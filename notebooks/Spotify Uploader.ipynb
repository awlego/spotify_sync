# %% [markdown]
# # Spotify Uploader
# a project to automatically create and update playlists on Spotify based on your listening history
#
# it also includes code for visualizing your listening history

# %% [markdown]
# # Setup

# %%
# Imports
# !pip3 install --upgrade pip
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install spotipy
# !pip3 install pprint
# !pip3 install requests
# !pip install matplotlib
# !pip install calplot
# !pip install python-decouple
# !pip install python-dotenv
# !pip install -r "requirements.txt"
# Out:
# Requirement already satisfied: pip in ./env3.10/lib/python3.10/site-packages (24.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# Successfully installed pip-25.0.1
# Requirement already satisfied: pandas in ./env3.10/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./env3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./env3.10/lib/python3.10/site-packages (from pandas) (2022.5)
# Requirement already satisfied: numpy>=1.21.0 in ./env3.10/lib/python3.10/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in ./env3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in ./env3.10/lib/python3.10/site-packages (1.23.4)
# Requirement already satisfied: spotipy in ./env3.10/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: redis>=3.5.3 in ./env3.10/lib/python3.10/site-packages (from spotipy) (4.3.4)
# Requirement already satisfied: requests>=2.25.0 in ./env3.10/lib/python3.10/site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: six>=1.15.0 in ./env3.10/lib/python3.10/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in ./env3.10/lib/python3.10/site-packages (from spotipy) (1.26.12)
# Requirement already satisfied: deprecated>=1.2.3 in ./env3.10/lib/python3.10/site-packages (from redis>=3.5.3->spotipy) (1.2.13)
# Requirement already satisfied: packaging>=20.4 in ./env3.10/lib/python3.10/site-packages (from redis>=3.5.3->spotipy) (21.3)
# Requirement already satisfied: async-timeout>=4.0.2 in ./env3.10/lib/python3.10/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./env3.10/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in ./env3.10/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env3.10/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (2022.9.24)
# Requirement already satisfied: wrapt<2,>=1.10 in ./env3.10/lib/python3.10/site-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.14.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./env3.10/lib/python3.10/site-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.6)
# Requirement already satisfied: requests in ./env3.10/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./env3.10/lib/python3.10/site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in ./env3.10/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./env3.10/lib/python3.10/site-packages (from requests) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in ./env3.10/lib/python3.10/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: matplotlib in ./env3.10/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in ./env3.10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./env3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: calplot in ./env3.10/lib/python3.10/site-packages (0.1.7.4)
# Requirement already satisfied: matplotlib in ./env3.10/lib/python3.10/site-packages (from calplot) (3.6.1)
# Requirement already satisfied: numpy in ./env3.10/lib/python3.10/site-packages (from calplot) (1.23.4)
# Requirement already satisfied: pandas>=1 in ./env3.10/lib/python3.10/site-packages (from calplot) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./env3.10/lib/python3.10/site-packages (from pandas>=1->calplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./env3.10/lib/python3.10/site-packages (from pandas>=1->calplot) (2022.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./env3.10/lib/python3.10/site-packages (from matplotlib->calplot) (3.0.6)
# Requirement already satisfied: six>=1.5 in ./env3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1->calplot) (1.16.0)
# Requirement already satisfied: python-decouple in ./env3.10/lib/python3.10/site-packages (3.6)
# Requirement already satisfied: python-dotenv in ./env3.10/lib/python3.10/site-packages (0.21.0)

# %%
# make sure your python path is your virtual environment.
import sys
sys.executable
# Out:
# '/Users/awlego/Repositories/spotify_sync/env3.10/bin/python3.10'

# %%
import pandas as pd
import numpy as np
import pytz 
import spotipy
import spotipy.util as util
import pprint
import requests
import matplotlib.pyplot as plt
import calplot
import calendar
import decouple
import re
import calendar


from datetime import datetime, timedelta

# %%
# %load_ext dotenv
# %dotenv

config = decouple.AutoConfig(' ')

MOST_LISTENED_TO_ID = config('MOST_LISTENED_TO_ID')
RECENT_FAVORITES_ID = config('RECENT_FAVORITES_ID')
BINGED_SONGS_ID = config('BINGED_SONGS_ID')
LASTFM_USERNAME = config('LASTFM_USERNAME')
SPOTIFY_USERNAME = config('SPOTIFY_USERNAME')

# %% [markdown]
# ## Spotify API Setup

# %%
scope = 'playlist-modify-private'
username = SPOTIFY_USERNAME
token = util.prompt_for_user_token(username, scope)
# print(token)

# %% [markdown]
# # Import Listening History and DO stuff

# %%
header_names = ["artist", "album", "song", "date_played"]
# spotify_history = pd.read_csv(f"{LASTFM_USERNAME}.csv", header=None, names=header_names)
spotify_history = pd.read_csv(f"awlego.csv", header=None, names=header_names)

spotify_history['date_played'] = pd.to_datetime(spotify_history['date_played'], utc=True, infer_datetime_format=True)
spotify_history['date_played'] = spotify_history['date_played'].dt.tz_convert('US/Pacific')
spotify_history = spotify_history.dropna()

# %% [markdown]
# ### Let's take a look at our dataframe to make sure we can see our history. If the history is long, you should see your newest 5 and oldest 5 listens.

# %%
spotify_history
# Out:
#                      artist  \
# 1         Penny and Sparrow
# 2                Tori Kelly
# 3            Zac Brown Band
# 4         Penny and Sparrow
# 5              Taylor Swift
# ...                     ...
# 66278  A Tribe Called Quest
# 66279  A Tribe Called Quest
# 66280  A Tribe Called Quest
# 66281  A Tribe Called Quest
# 66282           Canyon City
#
#                                                    album  \
# 1                                                  Finch
# 2                                                   Tori
# 3                                                Uncaged
# 4                                              Olly Olly
# 5                                               folklore
# ...                                                  ...
# 66278                                  The Love Movement
# 66279                                 Midnight Marauders
# 66280                                      The Anthology
# 66281  People's Instinctive Travels and the Paths of ...
# 66282                                    Paper Airplanes
#
#                                 song               date_played
# 1          Don't Wanna Be Without Ya 2024-09-27 15:05:00-07:00
# 2      young gun (feat. Jon Bellion) 2024-09-27 15:02:00-07:00
# 3                           The Wind 2024-09-27 14:59:00-07:00
# 4                             Gogogo 2024-09-27 14:55:00-07:00
# 5                              peace 2024-09-27 14:51:00-07:00
# ...                              ...                       ...
# 66278                     Find a Way 2019-03-19 18:40:00-07:00
# 66279                     Award Tour 2019-03-19 18:36:00-07:00
# 66280            Electric Relaxation 2019-03-19 18:33:00-07:00
# 66281                 Can I Kick It? 2019-03-19 18:28:00-07:00
# 66282                Paper Airplanes 2019-03-19 18:18:00-07:00
#
# [65952 rows x 4 columns]

# %% [markdown]
# ## calculate a bunch of interesting stuff

# %%
def calc_play_counts(history, album_different=True):
    if album_different:
        play_counts_df =  history.groupby(["artist", "album", "song"]).size().rename('play_count').reset_index().sort_values('play_count', ascending=False)
    else:
        play_counts_df =  history.groupby(["artist", "song"]).size().rename('play_count').reset_index().sort_values('play_count', ascending=False)
    return play_counts_df

calc_play_counts(spotify_history, album_different=True)
# Out:
#                   artist                                              album  \
# 11964  Penny and Sparrow                                              Finch
# 15115       Taylor Swift                                           folklore
# 17830     Zac Brown Band                                            Uncaged
# 15193       Tessa Violet                                          Bad Ideas
# 16008      The Oh Hellos                                   The Oh Hellos EP
# ...                  ...                                                ...
# 7682       Junior Senior  d-d-don't don't stop the beat (Explicit Conten...
# 7683             Juniper                                     Fresh Air Love
# 7688             Justice                                       Civilization
# 7689             Justice                                            Justice
# 18452                 태양                                               Rise
#
#                             song  play_count
# 11964  Don't Wanna Be Without Ya         207
# 15115     exile (feat. Bon Iver)         153
# 17830           Natural Disaster         145
# 15193                      Crush         123
# 16008         Hello My Old Heart         121
# ...                          ...         ...
# 7682              Move Your Feet           1
# 7683              Fresh Air Love           1
# 7688                Civilization           1
# 7689                        DVNO           1
# 18452       눈코입 (EYES NOSE LIPS)           1
#
# [18453 rows x 4 columns]

# %%
def get_most_played_artists(spotify_history):
    play_counts_df = calc_play_counts(spotify_history, True)
    return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)

get_most_played_artists(spotify_history)[0:30]
# Out:
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_6875/92459649.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
#                     play_count
# artist
# Taylor Swift              1770
# Penny and Sparrow         1565
# Bon Iver                  1558
# The Oh Hellos             1447
# Ed Sheeran                1440
# Jon Bellion               1106
# dodie                     1067
# Zac Brown Band            1036
# Lizzy McAlpine             974
# Tessa Violet               729
# Mat Kearney                706
# Muse                       679
# Jacob Collier              608
# Charlie Puth               597
# twenty one pilots          595
# Run River North            569
# Owl City                   561
# Mumford & Sons             558
# Camila Cabello             548
# Ariana Grande              461
# Jhameel                    439
# Sarah Jarosz               414
# Avi Kaplan                 408
# Porter Robinson            384
# Caroline Polachek          342
# Dave Matthews Band         331
# Walk the Moon              330
# Watsky                     330
# Mike Shinoda               328
# Coldplay                   315

# %%
def calc_most_listened_all_time(history, limit=50):
    counts = calc_play_counts(history, True)
    return counts.iloc[0:limit]
    

most_played = calc_most_listened_all_time(spotify_history)
most_played[0:10]
# Out:
#                   artist                      album  \
# 11964  Penny and Sparrow                      Finch
# 15115       Taylor Swift                   folklore
# 17830     Zac Brown Band                    Uncaged
# 15193       Tessa Violet                  Bad Ideas
# 16008      The Oh Hellos           The Oh Hellos EP
# 15122       Taylor Swift                   folklore
# 11959  Penny and Sparrow  Don't Wanna Be Without Ya
# 15984      The Oh Hellos              Dear Wormwood
# 1833            Bon Iver               22 a Million
# 18065              dodie                      Human
#
#                             song  play_count
# 11964  Don't Wanna Be Without Ya         207
# 15115     exile (feat. Bon Iver)         153
# 17830           Natural Disaster         145
# 15193                      Crush         123
# 16008         Hello My Old Heart         121
# 15122                      peace         117
# 11959  Don't Wanna Be Without Ya         115
# 15984          Soldier Poet King         114
# 1833                  8 (circle)         113
# 18065                    Monster         110

# %%
def calc_recent_favorites(history, limit=50, time_frame_days=30):
    time_frame = datetime.now(pytz.timezone('US/Pacific')) - timedelta(days=time_frame_days)
    history = history.loc[history['date_played'] > time_frame]
    counts = calc_play_counts(history)
    return counts.iloc[0:limit]
    
calc_recent_favorites(spotify_history, limit=25, time_frame_days=30)
# Out:
# Empty DataFrame
# Columns: [artist, album, song, play_count]
# Index: []

# %%
most_played = calc_most_listened_all_time(spotify_history, limit=5)
most_played.groupby('song').count()
# Out:
#                            artist  album  play_count
# song
# Crush                           1      1           1
# Don't Wanna Be Without Ya       1      1           1
# Hello My Old Heart              1      1           1
# Natural Disaster                1      1           1
# exile (feat. Bon Iver)          1      1           1

# %%
def calc_binged_songs(spotify_history, limit=25):
    spotify_history['day_played'] = spotify_history['date_played'].dt.date
    df =  spotify_history.groupby(["artist", "album", "song", "day_played"]).size().rename('daily_play_count').reset_index().sort_values('daily_play_count', ascending=False)
    df = df.where(df['daily_play_count'] >= 3).dropna()
    df = df.groupby(['artist', 'album', 'song'])['daily_play_count'].sum().rename('summed_top_daily_play_counts').reset_index().sort_values('summed_top_daily_play_counts', ascending=False)
    return df[0:limit]

# %%
def most_played_songs_by_artist(spotify_history, artist, limit=25):
    """
    Get the most played songs by a specific artist.
    
    Parameters:
    spotify_history (DataFrame): DataFrame containing Spotify listening history
    artist (str): Artist name to filter by
    limit (int): Maximum number of songs to return
    
    Returns:
    DataFrame: Most played songs by the specified artist
    """
    # Calculate play counts with metadata
    df = calc_play_counts(spotify_history)
    
    # Filter by artist and get top songs
    artist_songs = df[df['artist'] == artist].sort_values('play_count', ascending=False).head(limit)
    
    return artist_songs


most_played_songs_by_artist(spotify_history, 'Jacob Collier')
# Out:
#              artist                                              album  \
# 6398  Jacob Collier                                      Djesse Vol. 3
# 6391  Jacob Collier                                      Djesse Vol. 2
# 6451  Jacob Collier                 Little Blue (feat. Brandi Carlile)
# 6429  Jacob Collier                                      Djesse Vol. 4
# 6458  Jacob Collier  Wherever I Go (feat. Lawrence & Michael McDonald)
# 6389  Jacob Collier                                      Djesse Vol. 2
# 6408  Jacob Collier                                      Djesse Vol. 3
# 6373  Jacob Collier                                      Djesse Vol. 1
# 6407  Jacob Collier                                      Djesse Vol. 3
# 6440  Jacob Collier                   Here Comes The Sun (feat. dodie)
# 6385  Jacob Collier                                      Djesse Vol. 2
# 6393  Jacob Collier                                      Djesse Vol. 2
# 6459  Jacob Collier  Witness Me (feat. Shawn Mendes Stormzy & Kirk ...
# 6454  Jacob Collier  Never Gonna Be Alone (feat. Lizzy McAlpine & J...
# 6386  Jacob Collier                                      Djesse Vol. 2
# 6455  Jacob Collier               The Sun Is In Your Eyes (Voice Memo)
# 6404  Jacob Collier                                      Djesse Vol. 3
# 6401  Jacob Collier                                      Djesse Vol. 3
# 6387  Jacob Collier                                      Djesse Vol. 2
# 6403  Jacob Collier                                      Djesse Vol. 3
# 6399  Jacob Collier                                      Djesse Vol. 3
# 6392  Jacob Collier                                      Djesse Vol. 2
# 6400  Jacob Collier                                      Djesse Vol. 3
# 6406  Jacob Collier                                      Djesse Vol. 3
# 6396  Jacob Collier                                      Djesse Vol. 2
#
#                                                    song  play_count
# 6398          All I Need (with Mahalia & Ty Dolla $ign)          65
# 6391                                        Make Me Cry          38
# 6451                 Little Blue (feat. Brandi Carlile)          34
# 6429                                   She Put Sunshine          31
# 6458  Wherever I Go (feat. Lawrence & Michael McDonald)          24
# 6389                       It Don’t Matter (feat. JoJo)          22
# 6408          Time Alone With You (feat. Daniel Caesar)          20
# 6373                      All Night Long (feat. Take 6)          20
# 6407                              Sleeping On My Dreams          19
# 6440                   Here Comes The Sun (feat. dodie)          18
# 6385                       Feel (feat. Lianne La Havas)          16
# 6393                     Nebaluyo (feat. Oumou Sangaré)          14
# 6459  Witness Me (feat. Shawn Mendes Stormzy & Kirk ...          14
# 6454  Never Gonna Be Alone (feat. Lizzy McAlpine & J...          13
# 6386                   Here Comes The Sun (feat. dodie)          13
# 6455               The Sun Is In Your Eyes - Voice Memo          12
# 6404                     In Too Deep (feat. Kiana Ledé)          11
# 6401     Count The People (feat. Jessie Reyez & T-Pain)          10
# 6387  I Heard You Singing (feat. Becca Stevens & Chr...           9
# 6403   In My Bones (feat. Kimbra & Tank and The Bangas)           9
# 6399                                        Butterflies           8
# 6392                                         Moon River           8
# 6400                                            CLARITY           7
# 6406              Running Outta Love (feat. Tori Kelly)           7
# 6396                       Time To Rest Your Weary Head           6

# %% [markdown]
# ## Find future Afternoons with Alex candidates

# %%
# Define the get_playlist_songs function
def get_playlist_songs(playlist_id, token):
    sp = spotipy.Spotify(auth=token)
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Example usage:
# Replace 'your_playlist_id_here' with the actual playlist ID
AFTERNOONS_WITH_ALEX_ID = "626fRLNZLcGFS9Hm1zLAPO"
afternoons_with_alex_tracks = get_playlist_songs(AFTERNOONS_WITH_ALEX_ID, token)# for song in playlist_songs:#     print(song)

# %%
afternoons_with_alex_tracks[23]
# Out:
# {'added_at': '2018-02-10T01:37:41Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/awlego'},
#   'href': 'https://api.spotify.com/v1/users/awlego',
#   'id': 'awlego',
#   'type': 'user',
#   'uri': 'spotify:user:awlego'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/4309fadd9a0d573c1fafcca507e024b3bb51266b?cid=e04e8a864b5c45a2b4ed25907bcf3202',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/3mNoFlD1wsoXfkljfFzExT',
#    'id': '3mNoFlD1wsoXfkljfFzExT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27343294cfa2688055c9d821bf3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0243294cfa2688055c9d821bf3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485143294cfa2688055c9d821bf3',
#      'width': 64}],
#    'name': 'TALKING IS HARD',
#    'release_date': '2014-12-02',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:3mNoFlD1wsoXfkljfFzExT',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DIS6PRrLS3wbnZsf7vYic'},
#      'href': 'https://api.spotify.com/v1/artists/6DIS6PRrLS3wbnZsf7vYic',
#      'id': '6DIS6PRrLS3wbnZsf7vYic',
#      'name': 'WALK THE MOON',
#      'type': 'artist',
#      'uri': 'spotify:artist:6DIS6PRrLS3wbnZsf7vYic'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3mNoFlD1wsoXfkljfFzExT'},
#    'total_tracks': 12},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DIS6PRrLS3wbnZsf7vYic'},
#     'href': 'https://api.spotify.com/v1/artists/6DIS6PRrLS3wbnZsf7vYic',
#     'id': '6DIS6PRrLS3wbnZsf7vYic',
#     'name': 'WALK THE MOON',
#     'type': 'artist',
#     'uri': 'spotify:artist:6DIS6PRrLS3wbnZsf7vYic'}],
#   'disc_number': 1,
#   'track_number': 3,
#   'duration_ms': 199080,
#   'external_ids': {'isrc': 'USRC11401949'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4kbj5MwxO1bq9wjT5g9HaA'},
#   'href': 'https://api.spotify.com/v1/tracks/4kbj5MwxO1bq9wjT5g9HaA',
#   'id': '4kbj5MwxO1bq9wjT5g9HaA',
#   'name': 'Shut Up and Dance',
#   'popularity': 85,
#   'uri': 'spotify:track:4kbj5MwxO1bq9wjT5g9HaA',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
def songs_from_tracks(tracks):
    songs = []
    for track in tracks:
        t = track['track']
        songs.extend([(t['name'], t['artists'][0]['name'])])
    df = pd.DataFrame(songs, columns=['song', 'artist'])
    return df

afternoons_with_alex_songs = songs_from_tracks(afternoons_with_alex_tracks)
afternoons_with_alex_songs
# Out:
#                         song             artist
# 0                Lying Beast    Run River North
# 1                   Brothers  Penny and Sparrow
# 2                   Into You      Ariana Grande
# 3                     Pierre         Ryn Weaver
# 4              Below My Feet     Mumford & Sons
# ..                       ...                ...
# 700                   Mirror    Porter Robinson
# 701          Shade of Yellow              Griff
# 702                  Vertigo              Griff
# 703  You Can Close Your Eyes      Peter Hollens
# 704                   Gogogo  Penny and Sparrow
#
# [705 rows x 2 columns]

# %%
binged = calc_binged_songs(spotify_history, limit=100)
binged
# Out:
#                 artist                                              album  \
# 259  Penny and Sparrow                          Don't Wanna Be Without Ya
# 32            Bon Iver                                       U (Man Like)
# 58        Charlie Puth                                  Charlie Be Quiet!
# 396     Zac Brown Band                                            Uncaged
# 337       Taylor Swift                                           folklore
# ..                 ...                                                ...
# 107         Ed Sheeran                                         Bad Habits
# 160         Johnnyswim                                       Goodbye Road
# 77            Coldplay                               Music of the Spheres
# 89      Dwayne Johnson  Moana (Original Motion Picture Soundtrack/Delu...
# 371            Tove Lo                                Queen of the Clouds
#
#                           song  summed_top_daily_play_counts
# 259  Don't Wanna Be Without Ya                          42.0
# 32                U (Man Like)                          37.0
# 58           Charlie Be Quiet!                          31.0
# 396           Natural Disaster                          24.0
# 337                      peace                          19.0
# ..                         ...                           ...
# 107                 Bad Habits                           6.0
# 160          I Won't Back Down                           6.0
# 77                          ❤️                           6.0
# 89              You're Welcome                           6.0
# 371               Talking Body                           6.0
#
# [100 rows x 4 columns]

# %%
def find_nonmatching_songs(df1, df2, num_to_find):
    candidates = []
    # Define a simple function to remove punctuation and convert to lower case
    def clean_string(s):
        return re.sub(r'[^\w\s]', '', s).lower()
    
    i = 0
    while len(candidates) < num_to_find and len(df1) > 0:
        candidate = df1.head(1).reset_index(drop=True)
        df1 = df1.iloc[1:]

        # Clean the song and artist names for case-insensitive and punctuation-insensitive comparison
        song_clean = clean_string(candidate['song'].values[0])
        artist_clean = clean_string(candidate['artist'].values[0])

        is_present = ((df2['song'].apply(clean_string) == song_clean) & 
                    (df2['artist'].apply(clean_string) == artist_clean)).any()

        if not is_present:
            candidates.append(candidate)
        i += 1
    return candidates


def most_played_candidates(history, afternoons_with_alex_songs_df):
     # finds my 20 most played songs that are not in my Afternoons with Alex playlist
    NUM_MOST_PLAYED_TO_GET = 20
    most_played = calc_most_listened_all_time(history, limit=200)
    candidates = find_nonmatching_songs(most_played, afternoons_with_alex_songs_df, NUM_MOST_PLAYED_TO_GET)
   
    return candidates

def binged_candidates(history, afternoons_with_alex_songs_df):
    NUM_BINGED_TO_GET = 10
    binged = calc_binged_songs(history, limit=50)
    return find_nonmatching_songs(binged, afternoons_with_alex_songs_df, NUM_BINGED_TO_GET)

def date_within_last_n_days(date_series, n_days):
    # input_date = datetime.strptime(date_str, "%Y-%m-%d")
    # Convert date_series to datetime just in case it's not in datetime format
    current_date = pd.to_datetime(datetime.now().strftime('%Y-%m-%d'))
    
    # Get the current date with the time set to midnight for direct comparison with dates
    n_days_ago = current_date - pd.to_timedelta(n_days, unit='d')
    return (date_series >= n_days_ago) & (date_series <= current_date)

def find_future_AwA_candidates(history, afternoons_with_alex_songs_df):
    candidates = most_played_candidates(history, afternoons_with_alex_songs_df)
    # also finds the 10 most binged songs that are not in my Afternoons with Alex playlist
    candidates.append(binged_candidates(history, afternoons_with_alex_songs_df))
    # also finds the 5 most binged songs within the last month that are not in my Afternoons playlist    
    last_month_history = history[date_within_last_n_days(history['day_played'], 30)]
    candidates.append(binged_candidates(last_month_history, afternoons_with_alex_songs_df))

    return candidates

find_future_AwA_candidates(spotify_history, afternoons_with_alex_songs)
# Out:
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_30558/3973342146.py:45: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   return (date_series >= n_days_ago) & (date_series <= current_date)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_30558/158921151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spotify_history['day_played'] = spotify_history['date_played'].dt.date
# [          artist            song  play_count
#  0  The Oh Hellos  Constellations          65,
#       artist    song  play_count
#  0  Bon Iver  Hey Ma          59,
#                artist              song  play_count
#  0  Penny and Sparrow  Cult Classically          57,
#           artist                                     song  play_count
#  0  Charlie Puth  Left and Right (feat. Jung Kook of BTS)          53,
#           artist          song  play_count
#  0  Charlie Puth  Light Switch          53,
#                           artist             song  play_count
#  0  Drew Holcomb & the Neighbors  American Beauty          51,
#           artist    song  play_count
#  0  Tessa Violet  Feelin          50,
#            artist             song  play_count
#  0  Stuart Duncan  Here and Heaven          50,
#             artist      song  play_count
#  0  Lizzy McAlpine  erase me          48,
#       artist   song  play_count
#  0  Bon Iver  Faith          47,
#           artist           song  play_count
#  0  Bella Poarch  Build A Bitch          46,
#                artist      song  play_count
#  0  Penny and Sparrow  Need You          46,
#                artist      song  play_count
#  0  Penny and Sparrow  Recuerda          46,
#                artist    song  play_count
#  0  Penny and Sparrow  Eloise          44,
#       artist song  play_count
#  0  Bon Iver  iMi          44,
#         artist       song  play_count
#  0  Avi Kaplan  Otherside          43,
#            artist          song  play_count
#  0  The Oh Hellos  Bitter Water          42,
#       artist   song  play_count
#  0  Bon Iver  Salem          42,
#           artist        song  play_count
#  0  Charlie Puth  Empty Cups          42,
#             artist              song  play_count
#  0  Lizzy McAlpine  reckless driving          42,
#  [       artist                          album                           song  \
#   0  Tori Kelly  young gun (feat. Jon Bellion)  young gun (feat. Jon Bellion)
#
#      summed_top_daily_play_counts
#   0                          15.0  ,
#            artist          album           song  summed_top_daily_play_counts
#   0  Bella Poarch  Build a Bitch  Build A Bitch                          10.0,
#               artist                                              album  \
#   0  Auli'i Cravalho  Moana (Original Motion Picture Soundtrack/Delu...
#
#                 song  summed_top_daily_play_counts
#   0  How Far I'll Go                           9.0  ,
#        artist album song  summed_top_daily_play_counts
#   0  Bon Iver    ii   Yi                           9.0,
#                 artist  album              song  summed_top_daily_play_counts
#   0  Penny and Sparrow  Finch  Cult Classically                           7.0,
#        artist                 album      song  summed_top_daily_play_counts
#   0  Coldplay  Music of the Spheres  Biutyful                           7.0,
#             artist                             album          song  \
#   0  Walk the Moon  Walk The Moon (Expanded Edition)  Next in Line
#
#      summed_top_daily_play_counts
#   0                           7.0  ,
#       artist            album             song  summed_top_daily_play_counts
#   0  J. Maya  Ms. Protagonist  Ms. Protagonist                           7.0],
#  []]

# %%
afternoons_with_alex_songs['song'].where(afternoons_with_alex_songs['artist'] == "Ed Sheeran").dropna()
# Out:
# 138                                  Supermarket Flowers
# 291    South of the Border (feat. Camila Cabello & Ca...
# 293           Remember The Name (feat. Eminem & 50 Cent)
# 311                      Beautiful People (feat. Khalid)
# 527                                                 Nina
# 543                                           Bad Habits
# 569                                        Stop The Rain
# Name: song, dtype: object

# %%
afternoons_with_alex_songs['song'].where(afternoons_with_alex_songs['song'] == "Remember The Name (feat. Eminem & 50 Cent)").dropna()
# Out:
# 293    Remember The Name (feat. Eminem & 50 Cent)
# Name: song, dtype: object

# %% [markdown]
# # Make & Update Some Playlists!

# %% [markdown]
# ### Define the playlist creation/modification code

# %%
def make_playlist(username, token, playlist_name, playlist_description):
    if token:
        sp = spotipy.Spotify(auth=token)
        sp.trace = False
        playlists = sp.user_playlist_create(username, playlist_name,
                                            playlist_description)
    else:
        print("Can't get token for", username)
    return playlists


def playlist_replace_tracks(username, token, playlist_id, tracks):
    if token:
        sp = spotipy.Spotify(auth=token)
        sp.trace = True
        playlists = sp.user_playlist_replace_tracks(username, playlist_id, tracks)
    else:
        print("Can't get token for", username)
    return playlists


def lookup_track(artist, album, song, token):
    sp = spotipy.Spotify(auth=token)
    probable_song_name = song
    search_result = sp.search(f'{probable_song_name} {artist} {album}')
    try:
        result = search_result['tracks']['items'][0]['id']
    except (KeyError, IndexError):
        result = None
        pass
    return result

    
def make_recent_favorites(username, token):
    recent_favs = calc_recent_favorites(spotify_history, limit=25, time_frame_days=30)
    recent_favs['spotify_id'] = recent_favs.apply(lambda x: lookup_track(x['artist'], x['album'], x['song'], token), axis=1)
    
    track_ids = recent_favs['spotify_id']
    if token:
        playlist_results = make_playlist(username, token, "Recent Favorites", False)
        print(playlist_results)
        sp = spotipy.Spotify(auth=token)
        sp.user_playlist_add_tracks(username, playlist_results['id'], track_ids)
    else:
        print("Can't get token for", username)
        
        
def update_recent_favorites(username, token, playlist_id):
    recent_favs = calc_recent_favorites(spotify_history, limit=25, time_frame_days=30)
    # apparently some songs fail if they have really long titles
    recent_favs['spotify_id'] = recent_favs.apply(lambda x: lookup_track(x['artist'][0:15], x['album'][0:15], x['song'][0:15], token), axis=1)
    track_ids = recent_favs['spotify_id']
    track_ids = track_ids.dropna()

    playlist_results = playlist_replace_tracks(username, token, playlist_id, track_ids)

# I keep this code around to debug errors that I sometimes get.
# every once in a while a song comes up that breaks the way I'm doing things and I need
# to fix it.
# lookup_track("Daft Punk", "Random Access Memories", "Instant Crush feat. Julian Casablancas", token)
# scope = 'playlist-modify-private'
# username = SPOTIFY_USERNAME
# token = util.prompt_for_user_token(username, scope)
# make_playlist(username, token, "my_api_playlist", False)
# make_recent_favorites(username, token)
# update_recent_favorites(username, token, RECENT_FAVORITES_ID)

# recent_favs = calc_recent_favorites(spotify_history, limit=25, time_frame_days=30)
# recent_favs

# %%
result = lookup_track('Taylor Swift', '1989', 'Blank Space', token)
print(result)
# Out:
# 45wMBGri1PORPjM9PwFfrS

# %%
def update_binged_songs(username, token):
    binged_songs = calc_binged_songs(spotify_history)
    binged_songs['spotify_id'] = binged_songs.apply(lambda x: lookup_track(x['artist'], x['album'], x['song'], token), axis=1)
    track_ids = binged_songs['spotify_id']
    track_ids = track_ids.dropna()
    playlist_results = playlist_replace_tracks(username, token, BINGED_SONGS_ID, track_ids)
    
print(calc_binged_songs(spotify_history))
# update_binged_songs(username, token)
# Out:
#                 artist                           album  \
# 259  Penny and Sparrow       Don't Wanna Be Without Ya
# 32            Bon Iver                    U (Man Like)
# 58        Charlie Puth               Charlie Be Quiet!
# 396     Zac Brown Band                         Uncaged
# 337       Taylor Swift                        folklore
# 268  Penny and Sparrow                          Gogogo
# 398     Zac Brown Band                         Uncaged
# 369         Tori Kelly   young gun (feat. Jon Bellion)
# 264  Penny and Sparrow                           Finch
# 157            Jhameel                           Waves
# 336       Taylor Swift                        folklore
# 356       The Mowgli's            Waiting for the Dawn
# 216        Mat Kearney                       CRAZYTALK
# 45      Camila Cabello                         Familia
# 385               Yama                 Haru wo Tsugeru
# 13          Avi Kaplan                     I'll Get By
# 412              dodie                        You - EP
# 74            Coldplay            Music of the Spheres
# 190     Lizzy McAlpine  erase me (feat. Jacob Collier)
# 414      eleventyseven   Attack of The Mountain Medley
# 109         Ed Sheeran     No.6 Collaborations Project
# 22        Bella Poarch                   Build a Bitch
# 24            Big Wild                      Superdream
# 281    Porter Robinson                         Nurture
# 397     Zac Brown Band                         Uncaged
#
#                                            song  summed_top_daily_play_counts
# 259                   Don't Wanna Be Without Ya                          42.0
# 32                                 U (Man Like)                          37.0
# 58                            Charlie Be Quiet!                          31.0
# 396                            Natural Disaster                          24.0
# 337                                       peace                          19.0
# 268                                      Gogogo                          16.0
# 398                                    The Wind                          16.0
# 369               young gun (feat. Jon Bellion)                          15.0
# 264                   Don't Wanna Be Without Ya                          15.0
# 157                            Pursuit of Glory                          14.0
# 336                      exile (feat. Bon Iver)                          13.0
# 356                               San Francisco                          13.0
# 216                       Sleeping At The Wheel                          12.0
# 45                   Bam Bam (feat. Ed Sheeran)                          11.0
# 385                             Haru wo Tsugeru                          11.0
# 13                                  It Knows Me                          11.0
# 412                               In The Middle                          11.0
# 74                          People of the Pride                          11.0
# 190              erase me (feat. Jacob Collier)                          11.0
# 414                       All The Doubt In Town                          10.0
# 109  Remember the Name (feat. Eminem & 50 Cent)                          10.0
# 22                                Build A Bitch                          10.0
# 24                                   6's to 9's                           9.0
# 281                                 Wind Tempos                           9.0
# 397           Overnight (Feat. Trombone Shorty)                           9.0

# %%
def update_most_listened_all_time(username, token, playlist_id):
    most_listened_df = calc_most_listened_all_time(spotify_history)
    most_listened_df['spotify_id'] = most_listened_df.apply(lambda x: lookup_track(x['artist'], x['album'], x['song'], token), axis=1)
    track_ids = most_listened_df['spotify_id']
    track_ids = track_ids.dropna()
    playlist_results = playlist_replace_tracks(username, token, playlist_id, track_ids)
    
update_most_listened_all_time(username, token, MOST_LISTENED_TO_ID)

# %%
def update_playlist(username, token, playlist_id, calc_func):
    df = calc_func(spotify_history)
    df['spotify_id'] = df.apply(lambda x: lookup_track(x['artist'], x['album'], x['song'], token), axis=1)
    track_ids = df['spotify_id']
    track_ids = track_ids.dropna()
    playlist_results = playlist_replace_tracks(username, token, playlist_id, track_ids)

# %% [markdown]
# ## Create the playlists
# This only needs to be run once. Uncomment to create the playlists. You will need to take the IDs here and add them to your .env file

# %%
# # make my most listened to playlist and print it so I can get the ID
# print(make_playlist(username, token, "Most Listened To", False))
# print(make_playlist(username, token, "Binged Songs", False))
# idk why I made this one different but I did
# make_recent_favorites()

# %% [markdown]
# ## Actually update the playlists!

# %%
def update_all_playlists(username, token):
#     for key in AUTOGENERATED_PLAYLISTS:
#         update_playlist(username, token, playlist[AUTOGENERATED_PLAYLISTS[key]])
    update_most_listened_all_time(username, token, MOST_LISTENED_TO_ID)
    update_recent_favorites(username, token, RECENT_FAVORITES_ID)
    update_binged_songs(username, token)

update_all_playlists(username, token)

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %% [markdown]
# # Visualizations / Data

# %%
def calc_play_times(history):
    df = history
    df['day_of_week_played_en'] = df['date_played'].apply(lambda x: calendar.day_name[x.weekday()])
    df['day_of_week_played_num'] = df['date_played'].apply(lambda x: x.weekday())
    
    df = df.groupby(['day_of_week_played_num', 'day_of_week_played_en']).count()
    df = df.rename(columns={'day_played': 'play_count'})
    df = df.filter(['play_count'], axis='columns')    
    df.plot.bar(title="Awlego's Spotify Playcount by Day of Week")
    
def calc_cal_heatmap(spotify_history, artist_filter=None):
    spotify_history['day_played_datetime'] = spotify_history['date_played'].dt.date
    if artist_filter:
        spotify_history = spotify_history.where(spotify_history['artist'] == artist_filter).dropna()
    df = spotify_history.groupby('day_played').count()
    
    df = spotify_history.set_index(['date_played'])
    df['number'] = 1
    

    if artist_filter:
        title = f'Number of {artist_filter} Songs Played on Spotify by awlego'
    else:
        title = 'Number of Songs Played on Spotify by awlego'

    ax = calplot.calplot(df['number'], cmap='YlGn', dropzero=True, edgecolor=None, colorbar=True, suptitle=title)
# calc_play_times(spotify_history)
# calc_cal_heatmap(spotify_history)
calc_cal_heatmap(spotify_history, artist_filter=None)
# Out:
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(

# %%
def most_consistently_listened_to_artists(spotify_history):
    df = spotify_history.groupby(['artist', 'day_played_datetime'])['day_played_datetime'].count().reset_index(name="num_artist_play_days")
    df = df.sort_values('num_artist_play_days', ascending=False)
    print(df[0:10])

most_consistently_listened_to_artists(spotify_history)
# Out:
#                    artist day_played_datetime  num_artist_play_days
# 11786       Hayden Calnin          2023-11-17                    75
# 20103         Mat Kearney          2019-09-18                    73
# 29055  Soft Romantic Jazz          2022-12-17                    70
# 14758         Jon Bellion          2019-04-11                    60
# 5163    Caroline Polachek          2023-05-04                    55
# 32705       The Oh Hellos          2019-08-01                    55
# 30169        Taylor Swift          2019-05-06                    55
# 36470      Zac Brown Band          2021-11-03                    54
# 14246           Jim Yosef          2022-09-01                    54
# 8684           Ed Sheeran          2021-10-30                    54

# %% [markdown]
# ## 2023 Wrapped

# %%
df_2023 = spotify_history.where(spotify_history['date_played'].dt.year == 2023).dropna()

# %% [markdown]
# ## Number of songs listened to

# %%
len(df_2023)
# Out:
# 10268

# %% [markdown]
# interesting... spotify claims I played 4,599 songs in 2023. I have over 10,000. Someone's data is bad.

# %% [markdown]
# ## Most played song

# %%
calc_play_counts(df_2023).iloc[0]
# Out:
# artist                        Caroline Polachek
# song          So Hot You're Hurting My Feelings
# play_count                                   42
# Name: 538, dtype: object

# %% [markdown]
# Okay closer agreement here: spotify says 43 times and agrees that this was my top song

# %%
calc_play_counts(df_2023).iloc[0:10]
# Out:
#                  artist                               song  play_count
# 538   Caroline Polachek  So Hot You're Hurting My Feelings          42
# 1819               Kara                        WHEN I MOVE          38
# 4157      eleventyseven              All The Doubt In Town          33
# 4051     Zac Brown Band                   Natural Disaster          32
# 2003     Lizzy McAlpine                      all my ghosts          32
# 572        Charlie Puth                  Charlie Be Quiet!          31
# 2011     Lizzy McAlpine                           erase me          31
# 514   Caroline Polachek                   Blood and Butter          30
# 1362       Hugh Jackman                        From Now On          30
# 467      Camila Cabello         Bam Bam (feat. Ed Sheeran)          30

# %% [markdown]
# this more or less matches spotify's records

# %% [markdown]
# ## Number of unique artists I listened to this year

# %%
# spotify says I listened to 2,342 artists this year.
len(df_2023['artist'].unique())
# Out:
# 1560

# %% [markdown]
# I bet the difference is I'm only tracking the first artist on a track

# %% [markdown]
# ## Favorite artists this year

# %%
get_most_played_artists(df_2023)[0:10]
# Out:
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
#                    play_count
# artist
# Lizzy McAlpine            316
# Caroline Polachek         269
# Taylor Swift              246
# Ed Sheeran                185
# Tessa Violet              141
# Zac Brown Band            138
# The Oh Hellos             131
# dodie                     121
# Noah Kahan                120
# Jon Bellion               120

# %%
for i in range(5):
    calc_cal_heatmap(df_2023, artist_filter=get_most_played_artists(df_2023).iloc[i].name)
# Out:
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(

# %%
def peak_listening_month(spotify_history, artist):
    spotify_history['day_played_datetime'] = pd.to_datetime(spotify_history['day_played_datetime'])
    spotify_history['month'] = spotify_history['day_played_datetime'].dt.month
    artist_history = spotify_history.where(spotify_history['artist'] == artist)
    play_counts_df =  artist_history.groupby(["month"]).size().rename('play_count').reset_index().sort_values('play_count', ascending=False)
    return play_counts_df
    # return play_counts_df.groupby('artist').sum().groupby("month").sum().sort_values('play_count', ascending=False)
peak_listening_month(df_2023, get_most_played_artists(df_2023).iloc[0].name)
# Out:
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
#     month  play_count
# 8     9.0          73
# 10   11.0          66
# 2     3.0          49
# 1     2.0          29
# 9    10.0          26
# 4     5.0          22
# 3     4.0          18
# 6     7.0          14
# 0     1.0          10
# 7     8.0           5
# 5     6.0           4

# %%
MONTH_NUMBER_TO_NAME = {
    "1": "January",
    "2": "February",
    "3": "March",
    "4": "April",
    "5": "May",
    "6": "June",
    "7": "July",
    "8": "August",
    "9": "September",
    "10": "October",
    "11": "November",
    "12": "December",
}

# %%
for i in range(5):
    peak_artist = get_most_played_artists(df_2023).iloc[i].name
    df = peak_listening_month(df_2023, peak_artist)
    peak_month_name = MONTH_NUMBER_TO_NAME[str(int(df.iloc[0].month))]
    peak_month_playcounts= [str(int(df.iloc[0].play_count))]
    print(f"You listened to {peak_artist} {peak_month_playcounts} times in {peak_month_name}")
# Out:
# You listened to Lizzy McAlpine ['73'] times in September
# You listened to Caroline Polachek ['128'] times in May
# You listened to Taylor Swift ['57'] times in February
# You listened to Ed Sheeran ['61'] times in May
# You listened to Tessa Violet ['71'] times in October
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_31098/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)

# %% [markdown]
# ## What day of the week do I listen to the most music

# %%
DAY_NAMES_DICT = dict(zip(calendar.day_name, range(7)))
print(DAY_NAMES_DICT)

import pandas as pd

def play_counts_by_dow(df):
    '''Calculates the number of plays on each day of the week, returning them sorted by day of week.'''
    df['day_played_datetime'] = pd.to_datetime(df['day_played_datetime'])
    df['weekday'] = df['day_played_datetime'].dt.strftime('%A')

    # Define the correct order for the days of the week
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

    # Group by weekday and count the plays
    df = df.groupby(['weekday']).size().rename('play_count')

    # Convert the index to a CategoricalIndex with the defined order
    df.index = pd.CategoricalIndex(df.index, categories=days, ordered=True)

    # Sort by the index (i.e., day of the week)
    df = df.sort_index()

    return df



dow_df = play_counts_by_dow(df_2023)
dow_df.plot.bar(x='weekday', xlabel="Weekday", ylabel='Song Play Count')
# Out:
# {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_30558/2329702026.py in <module>
#      25
#      26
# ---> 27 dow_df = play_counts_by_dow(df_2023)
#      28 dow_df.plot.bar(x='weekday', xlabel="Weekday", ylabel='Song Play Count')
#
# NameError: name 'df_2023' is not defined

# %% [markdown]
# ## 2023 heatmap

# %%
calc_cal_heatmap(df_2023, artist_filter=None)
# Out:
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(

# %%
calc_cal_heatmap(spotify_history, artist_filter="Lizzy McAlpine")
# Out:
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:153: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   plot_data = by_day.pivot('day', 'week', 'data').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:157: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fill_data = by_day.pivot('day', 'week', 'fill').values[::-1]
# /Users/awlego/Repositories/spotify_sync/env3.10/lib/python3.10/site-packages/calplot/calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(

# %%
df_2023.where(df_2023['song'] == "The Joker And The Queen").dropna()
# Out:
# Empty DataFrame
# Columns: [artist, album, song, date_played, day_played, day_played_datetime, month, day, weekday, weekday_num]
# Index: []

# %% [markdown]
# # Stop
# this should throw an error so you can hit "run all cells" without worrying about the playground going wild

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_95975/3957423419.py in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # Playground
# below here I promise nothing

# %%
#todo
# combine the multiple versions of songs together and pick the one that I have saved and if not saved then the one that I have more playcounts for.

# %%
def find_standout_songs(spotify_history, timewindow):
    df = calc_play_counts(spotify_history)
    
# find_standout_songs(spotify_history)

# %%
# def update_recently_played(username, token, playlist_id):
    
def recently_played():
    """Calculates the last 50 songs played."""
    pass

# %%
def save_all_liked_songs():
    """save a list of all the songs I've added to my library so if I ever lose it
    I could rebuild my library"""
    sp = spotipy.Spotify()

    scope = 'user-library-read'

    username = SPOTIFY_USERNAME

    token = util.prompt_for_user_token(username, scope)

    if token:
        sp = spotipy.Spotify(auth=token)
        results = sp.current_user_saved_tracks()
        for item in results['items']:
            track = item['track']
            print(track['name'] + ' - ' + track['artists'][0]['name'])
    else:
        print("Can't get token for", username)

# %% [markdown]
# ## testing directly getting my lastfm data

# %%
requests.get('https://api.github.com')

# %%
data = {
    'method':'user.getrecenttracks',
    'user':username,
    'api_key':'e8db1a5e26f01ca1abae47d64738e9b4',
    'limit':200,
    'page': 1,
}

response = requests.post("https://ws.audioscrobbler.com/2.0/", data=data)
# json_response = response.json()

# %%
response.status_code

# %%
import xml.etree.ElementTree as ET
import json

# !pip3 install xmljson
from xmljson import badgerfish as bf

# %%
tree = ET.fromstring(response.text)
tree

# %%
temp = json.dumps(bf.data(tree))
df = pd.read_json(temp)

# %%
df

# %%
temp

# %%
scope = 'user-read-recently-played'
token = util.prompt_for_user_token(username, scope)
header = {
   "access_token": token,
   'Authorization': 'Bearer {0}'.format(token),
}
data = {
    'limit': 50
}

# note: songs have to finish for this to catch them.
response = requests.get('https://api.spotify.com/v1/me/player/recently-played',
                        headers=header,
                        params=data)

# %%
print(response.status_code)
for item in response.json()['items']:
    print(item['track']['name'])
#     print(item['track'])

# %%
twenty_twenty_history = spotify_history.where(spotify_history['date_played'].dt.year == 2020).dropna()

# %%
history_2022 = spotify_history.where(spotify_history['date_played'].dt.year == 2022).dropna()

# %%
calc_most_listened_all_time(twenty_twenty_history)

# %%
get_most_played_artists(twenty_twenty_history)[0:10]

# %%
get_most_played_artists(spotify_history)[0:10]

# %%
history_2021 = spotify_history.where(spotify_history['date_played'].dt.year == 2021).dropna()

# %%
calc_most_listened_all_time(history_2021)

# %%
get_most_played_artists(history_2022)[0:15]
# Out:
# /var/folders/_4/45mv5nqd1m1_xtw1k2q21zdc0000gn/T/ipykernel_95975/2322836080.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return play_counts_df.groupby('artist').sum().sort_values('play_count', ascending=False)
#                    play_count
# artist
# Lizzy McAlpine            382
# Charlie Puth              287
# Zac Brown Band            270
# Penny and Sparrow         244
# Taylor Swift              181
# dodie                     176
# Camila Cabello            166
# Ed Sheeran                165
# Bon Iver                  144
# TWICE                     141
# MAMAMOO                   123
# Marianas Trench           122
# Yama                      120
# Hayden Calnin             115
# Porter Robinson           105

# %%
history_2022
# Out:
#                  artist                                     album  \
# 0          Neural Cloud                           Up To The Cloud
# 1             Alonestar          Real Life [Jethro Sheeran Remix]
# 2               J. Maya                            Three Specters
# 3                  Muse  Ghosts (How Can I Move On) [feat. Elisa]
# 4       The Paper Kites                                  Woodland
# ...                 ...                                       ...
# 10211  Laura Bell Bundy                         Women of Tomorrow
# 10212        Avi Kaplan                               I'll Get By
# 10213         Lil Nas X            MONTERO (Call Me by Your Name)
# 10214              K/DA                                   ALL OUT
# 10215     Jacob Collier                             Djesse Vol. 2
#
#                                            song               date_played  \
# 0                               Up To The Cloud 2022-11-29 15:29:00-08:00
# 1              Real Life [Jethro Sheeran Remix] 2022-11-29 15:25:00-08:00
# 2                                Three Specters 2022-11-29 15:21:00-08:00
# 3      Ghosts (How Can I Move On) [feat. Elisa] 2022-11-29 15:17:00-08:00
# 4                             Willow Tree March 2022-11-27 21:44:00-08:00
# ...                                         ...                       ...
# 10211                        Get It Girl You Go 2022-01-03 21:27:00-08:00
# 10212                               I'll Get By 2022-01-03 21:23:00-08:00
# 10213            MONTERO (Call Me by Your Name) 2022-01-03 21:21:00-08:00
# 10214                               DRUM GO DUM 2022-01-03 21:18:00-08:00
# 10215                               Make Me Cry 2022-01-03 21:14:00-08:00
#
#        day_played day_played_datetime
# 0      2022-11-29          2022-11-29
# 1      2022-11-29          2022-11-29
# 2      2022-11-29          2022-11-29
# 3      2022-11-29          2022-11-29
# 4      2022-11-27          2022-11-27
# ...           ...                 ...
# 10211  2022-01-03          2022-01-03
# 10212  2022-01-03          2022-01-03
# 10213  2022-01-03          2022-01-03
# 10214  2022-01-03          2022-01-03
# 10215  2022-01-03          2022-01-03
#
# [10216 rows x 6 columns]

# %%
calc_play_counts(history_2022)[0:30]
# Out:
#                    artist                                    album  \
# 3890       Zac Brown Band                                  Uncaged
# 2661    Penny and Sparrow                                    Finch
# 3893       Zac Brown Band                                  Uncaged
# 2003       Lizzy McAlpine           erase me (feat. Jacob Collier)
# 2000       Lizzy McAlpine                            all my ghosts
# 576          Charlie Puth                        Charlie Be Quiet!
# 2147      Marianas Trench                                  Astoria
# 1725                 K/DA                                  ALL OUT
# 510        Camila Cabello                                  Familia
# 3781         Wilder Woods                             Wilder Woods
# 3823                 XYLØ                                 yes & no
# 591          Charlie Puth                               Voicenotes
# 3827                 Yama                          Haru wo Tsugeru
# 2788       Punch Brothers                    Hell on Church Street
# 642          Clean Bandit                                 New Eyes
# 2101              MAMAMOO                         reality in BLACK
# 2989         Sara Hartman                                Satellite
# 1962       Lizzy McAlpine                        Five Seconds Flat
# 3027            Seraphine                                POP/STARS
# 2888  Roses & Revolutions                                   Coffee
# 579          Charlie Puth  Left and Right (feat. Jung Kook of BTS)
# 1967       Lizzy McAlpine                        Five Seconds Flat
# 1576   John Mark McMillan                      Peopled With Dreams
# 1218        Hayden Calnin                              Let's Dance
# 3348         Tessa Violet                                  YES MOM
# 298            Ben Howard                   I Forget Where We Were
# 704       Cosmo Sheldrake              The Much Much How How and I
# 1237        Hayden Calnin                What It Means To Be Human
# 2764      Porter Robinson                                  Nurture
# 2410               NAYEON                                IM NAYEON
#
#                                           song  play_count
# 3890                          Natural Disaster          65
# 2661                 Don't Wanna Be Without Ya          50
# 3893                                  The Wind          46
# 2003            erase me (feat. Jacob Collier)          42
# 2000                             All My Ghosts          41
# 576                          Charlie Be Quiet!          37
# 2147                           Who Do You Love          34
# 1725                               DRUM GO DUM          34
# 510                 Bam Bam (feat. Ed Sheeran)          33
# 3781                           Supply & Demand          33
# 3823                                  yes & no          32
# 591                                 Empty Cups          31
# 3827                           Haru wo Tsugeru          29
# 2788                              Pride of Man          29
# 642   A+E (feat. Kandaka Moore & Nikki Cislyn)          28
# 2101                                       HIP          28
# 2989                      Monster Lead Me Home          28
# 1962                             All My Ghosts          27
# 3027                                 POP/STARS          27
# 2888                                    Coffee          26
# 579    Left and Right (feat. Jung Kook of BTS)          26
# 1967                                  doomsday          26
# 1576                                   Pilgrim          26
# 1218                               Let's Dance          25
# 3348                                   YES MOM          25
# 298                                  In Dreams          25
# 704                              Birthday Suit          25
# 1237                      We Got Gods to Blame          24
# 2764                      Something Comforting          24
# 2410                                      POP!          24

# %%
header_names = ["full_date", "date", "time", "mood", "activities", "notes_title", "note"]
mood_history = pd.read_csv("daylio_export_2023_10_06.csv", header=0, names=header_names)

# %%
mood_history
# Out:
#            full_date       date      time  mood  \
# 2023-10-06     Oct 6     Friday   1:16 AM   rad
# 2023-10-05     Oct 5   Thursday   2:33 AM  good
# 2023-10-04     Oct 4  Wednesday   2:53 AM  good
# 2023-10-03     Oct 3    Tuesday   2:42 AM  good
# 2023-10-02     Oct 2     Monday   2:12 AM  meh+
# ...              ...        ...       ...   ...
# 2022-11-09     Nov 9  Wednesday   1:00 AM   rad
# 2022-11-08     Nov 8    Tuesday   1:00 AM   meh
# 2022-11-06     Nov 6     Sunday  11:59 PM   rad
# 2022-11-06     Nov 6     Sunday   9:33 AM   rad
# 2022-11-05     Nov 5   Saturday   1:00 AM  good
#
#                                                    activities  notes_title  \
# 2023-10-06  date | movies & tv | gaming | good sleep | hom...          NaN
# 2023-10-05  friends | gaming | project | good sleep | medi...          NaN
# 2023-10-04  reading | gaming | board games | medium sleep ...          NaN
# 2023-10-03  friends | movies & tv | reading | gaming | goo...          NaN
# 2023-10-02  friends | date | movies & tv | reading | gamin...          NaN
# ...                                                       ...          ...
# 2022-11-09  date | movies & tv | gaming | good sleep | hom...          NaN
# 2022-11-08  movies & tv | gaming | project | medium sleep ...          NaN
# 2022-11-06  friends | party | gaming | bad sleep | homemad...          NaN
# 2022-11-06  friends | party | gaming | bad sleep | homemad...          NaN
# 2022-11-05  friends | gaming | good sleep | restaurant | m...          NaN
#
#            note
# 2023-10-06  NaN
# 2023-10-05  NaN
# 2023-10-04  NaN
# 2023-10-03  NaN
# 2023-10-02  NaN
# ...         ...
# 2022-11-09  NaN
# 2022-11-08  NaN
# 2022-11-06  NaN
# 2022-11-06  NaN
# 2022-11-05  NaN
#
# [364 rows x 7 columns]

# %%
mood_history.index
# Out:
# Index(['2023-10-06', '2023-10-05', '2023-10-04', '2023-10-03', '2023-10-02',
#        '2023-10-01', '2023-09-30', '2023-09-29', '2023-09-28', '2023-09-27',
#        ...
#        '2022-11-14', '2022-11-13', '2022-11-12', '2022-11-11', '2022-11-10',
#        '2022-11-09', '2022-11-08', '2022-11-06', '2022-11-06', '2022-11-05'],
#       dtype='object', length=364)

# %%
mood_history.index = pd.to_datetime(mood_history.index)

# %%
mood_history["true_date"] = mood_history.index - pd.Timedelta(days=1)

# %%
simple_mood_history = mood_history[["true_date", "mood"]]
simple_mood_history = simple_mood_history.set_index("true_date")
simple_mood_history
# Out:
#             mood
# true_date
# 2023-10-05   rad
# 2023-10-04  good
# 2023-10-03  good
# 2023-10-02  good
# 2023-10-01  meh+
# ...          ...
# 2022-11-08   rad
# 2022-11-07   meh
# 2022-11-05   rad
# 2022-11-05   rad
# 2022-11-04  good
#
# [364 rows x 1 columns]

# %%
def get_genre(artist_name):
    sp = spotipy.Spotify(auth=token)  
    results = sp.search(q='artist:' + artist_name, type='artist')
    artist_id = results['artists']['items'][0]['id']  # Take the ID of the top result
    artist = sp.artist(artist_id)
    genres = artist['genres']
    return genres
# get_genre("Dodie")

# %%
def num_songs_played_by_date(spotify_history, artist_filter=None):
    spotify_history['day_played_datetime'] = spotify_history['date_played'].dt.date
    if artist_filter:
        spotify_history = spotify_history.where(spotify_history['artist'] == artist_filter).dropna()
    df = spotify_history.groupby('day_played_datetime').count()
    df = df.rename(columns={"artist": "num_songs_played"})
    return df["num_songs_played"]

def get_all_artists_genres(spotify_history):
    artist_genres = {}
    artists = spotify_history["artist"].unique()
    for artist in artists:
        try:
            artist_genres[artist] = get_genre(artist)
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
    return artist_genres

def genre_plays_per_day(spotify_history):
    spotify_history['day_played_datetime'] = spotify_history['date_played'].dt.date
    print(spotify_history.groupby("artist").count())
#     print(spotify_history.columns)

# print(num_songs_played_by_date(spotify_history, artist_filter="Taylor Swift"))
# print(genre_plays_per_day(spotify_history))
artist_genres = get_all_artists_genres(spotify_history)
# Out:
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range
# An error occurred: list index out of range

# %%
artist_genres
# Out:
# {'Emmylou Harris': ['country rock',
#   'folk',
#   'lilith',
#   'melancholia',
#   'singer-songwriter'],
#  'Billy Strings': ['jam band',
#   'jamgrass',
#   'new americana',
#   'progressive bluegrass'],
#  'Molly Tuttle': ['new americana', 'progressive bluegrass'],
#  'Whitney Rose': ['austin singer-songwriter', 'canadian contemporary country'],
#  'Andy Hall': ['instrumental bluegrass'],
#  'Sarah Jarosz': ['folk',
#   'indie folk',
#   'new americana',
#   'progressive bluegrass'],
#  'Steep Canyon Rangers': ['banjo',
#   'bluegrass',
#   'neo-traditional bluegrass',
#   'progressive bluegrass'],
#  'Chatham Rabbits': ['modern old-time'],
#  'Sierra Ferrell': ['alternative americana', 'new americana'],
#  'Susto': ['deep new americana', 'south carolina indie'],
#  'Mipso': ['new americana',
#   'north carolina roots',
#   'progressive bluegrass',
#   'stomp and holler'],
#  'The Pink Stones': ['alternative country'],
#  'Rachel Baiman': ['neo-traditional bluegrass'],
#  'Mumford & Sons': ['modern folk rock',
#   'modern rock',
#   'neo mellow',
#   'stomp and holler',
#   'uk americana'],
#  'Johnnyswim': ['acoustic pop', 'folk-pop'],
#  'Oh Wonder': ['electropop', 'indie poptimism', 'pov: indie'],
#  'Mother Mother': ['pov: indie', 'vancouver indie'],
#  'Kishi Bashi': ['chamber pop',
#   'metropopolis',
#   'shimmer pop',
#   'stomp and whittle'],
#  'Gary Jules': ['neo mellow'],
#  'Simon & Garfunkel': ['classic rock',
#   'folk',
#   'folk rock',
#   'melancholia',
#   'mellow gold',
#   'rock',
#   'soft rock'],
#  'Ingrid St-Pierre': ['indie quebecois'],
#  'The Arcadian Wild': ['indiecoustica'],
#  'Bon Iver': ['chamber pop',
#   'eau claire indie',
#   'indie folk',
#   'melancholia',
#   'modern rock'],
#  'The Outfield': ['album rock', 'power pop'],
#  'Jon Bellion': ['indie pop rap'],
#  'Josh Ritter': ['alternative country',
#   'indie folk',
#   'modern folk rock',
#   'new americana',
#   'stomp and holler'],
#  "Rag'n'Bone Man": [],
#  'Martin Garrix': ['dutch edm',
#   'edm',
#   'pop',
#   'pop dance',
#   'progressive house'],
#  'dodie': ['alt z', 'indie pop', 'pov: indie'],
#  'Tessa Violet': ['alt z', 'indie pop', 'pov: indie'],
#  'Austin Wintory': ['indie game soundtrack',
#   'orchestral soundtrack',
#   'video game music'],
#  'George Ezra': ['folk-pop', 'neo-singer-songwriter', 'talent show'],
#  'Idina Menzel': ['hollywood', 'movie tunes', 'show tunes'],
#  'Rodrigo y Gabriela': ['acoustic rock', 'world'],
#  'C.U.T.': ["children's music"],
#  'UNDRESSD': ['orebro indie'],
#  'Mullally': ['uk contemporary r&b'],
#  'Ed Sheeran': ['pop', 'singer-songwriter pop', 'uk pop'],
#  'Charlie Puth': ['pop', 'viral pop'],
#  'Daft Punk': ['electro', 'filter house', 'rock'],
#  'Quotes From Movies': [],
#  'Lizzy McAlpine': ['alt z',
#   'boston folk',
#   'indie pop',
#   'singer-songwriter pop'],
#  'Jacob Collier': ['uk alternative pop'],
#  'pH-1': ['k-rap', 'korean r&b'],
#  'West Rose': [],
#  'Ariana Grande': ['pop'],
#  'EquallyOpposite': [],
#  'Shoffy': ['chill pop', 'la pop'],
#  'Menna': [],
#  'Brooke Alexx': ['alt z', 'singer-songwriter pop'],
#  'Emei': ['alt z', 'singer-songwriter pop'],
#  'Caroline Polachek': ['art pop', 'escape room', 'indie pop', 'indietronica'],
#  'Scary Pockets': ['retro soul'],
#  'Caamp': ['indie folk', 'stomp and holler'],
#  'System of a Down': ['alternative metal', 'nu metal', 'rap metal', 'rock'],
#  'La La Land Cast': [],
#  'Ryan.B': ['chinese hip hop'],
#  'Audrey Assad': ['roots worship'],
#  'Em Beihold': ['alt z', 'gen z singer-songwriter'],
#  'Jónsi': ['icelandic pop', 'post-rock'],
#  'Nekokat': ['indie rockism'],
#  'Caravan Palace': ['electro swing', 'nu jazz'],
#  'Phlake': ['danish pop', 'scandinavian r&b'],
#  'Izzy Bizu': ['british soul'],
#  'Zach Bryan': ['classic oklahoma country', 'modern country pop'],
#  'Noah Kahan': ['pov: indie', 'singer-songwriter pop'],
#  'Regina Spektor': ['acoustic pop', 'indie pop', 'lilith', 'piano rock'],
#  'Seryn': ['denton tx indie', 'stomp and holler'],
#  'Brye': ['alt z', 'modern indie pop'],
#  'Will Joseph Cook': ['kent indie', 'modern alternative pop'],
#  'Chloe Moriondo': ['alt z', 'bedroom pop', 'indie pop', 'pov: indie'],
#  'Mrs. GREEN APPLE': ['anime rock', 'j-pop', 'j-rock'],
#  'Yama': ['j-pop', 'japanese teen pop'],
#  'Kiro Akiyama': ['j-rock'],
#  'MAISONdes': ['japanese teen pop'],
#  'jon-YAKITORY': ['anime'],
#  'Kanaria': ['vocaloid'],
#  'Iron & Wine': ['acoustic pop',
#   'chamber pop',
#   'indie folk',
#   'indie rock',
#   'stomp and holler'],
#  'Dua Lipa': ['dance pop', 'pop', 'uk pop'],
#  'Jung Kook': ['k-pop'],
#  'Ezra Vine': ['folk-pop', 'nz pop'],
#  'The Oh Hellos': ['folk-pop',
#   'pov: indie',
#   'san marcos tx indie',
#   'stomp and holler'],
#  'Stevie Wonder': ['motown', 'soul'],
#  'Matt Nathanson': ['acoustic pop', 'neo mellow'],
#  'Leslie Odom Jr.': ['broadway', 'show tunes', 'vocal jazz'],
#  'X Ambassadors': ['modern alternative rock', 'modern rock', 'stomp pop'],
#  'Hoodie Allen': ['indie pop rap'],
#  'Disturbed': ['alternative metal', 'nu metal', 'rap metal', 'rock'],
#  'Adam Young': [],
#  'Punch Brothers': ['banjo',
#   'bluegrass',
#   'indie folk',
#   'mandolin',
#   'new americana',
#   'progressive bluegrass'],
#  'Jhameel': ['shimmer pop'],
#  'Taylor Swift': ['pop'],
#  'Mike Posner': ['dance pop', 'pop', 'pop dance', 'pop rap'],
#  'Marvin Gaye': ['classic soul',
#   'motown',
#   'neo soul',
#   'northern soul',
#   'quiet storm',
#   'soul'],
#  'Bryan Adams': ['canadian pop',
#   'canadian singer-songwriter',
#   'classic canadian rock',
#   'heartland rock',
#   'mellow gold',
#   'soft rock'],
#  'Panama Wedding': ['hopebeat',
#   'indie poptimism',
#   'indietronica',
#   'shimmer pop'],
#  'Dizzy Gillespie': ['bebop',
#   'contemporary post-bop',
#   'jazz',
#   'jazz trumpet',
#   'vocal jazz'],
#  'Mika': ['electropop'],
#  'Of Monsters and Men': ['folk-pop',
#   'metropopolis',
#   'modern rock',
#   'stomp and holler'],
#  'Robyn': ['dance pop',
#   'electropop',
#   'neo-synthpop',
#   'scandipop',
#   'swedish electropop',
#   'swedish pop'],
#  'Daughtry': ['alternative metal', 'neo mellow', 'pop rock', 'post-grunge'],
#  "Tow'rs": [],
#  'Delta Rae': ['folk-pop'],
#  'Kygo': ['edm', 'pop', 'pop dance', 'tropical house'],
#  'Parade of Lights': ['hopebeat',
#   'indie poptimism',
#   'metropopolis',
#   'shimmer pop'],
#  'Ben Howard': ['british singer-songwriter', 'folk-pop'],
#  'Katy Perry': ['pop'],
#  'The Classic Crime': ['christian alternative rock', 'christian rock'],
#  'Vampire Weekend': ['baroque pop',
#   'chamber pop',
#   'garage rock',
#   'indie rock',
#   'indietronica',
#   'modern rock'],
#  'Stuart Duncan': ['bluegrass fiddle', 'progressive bluegrass'],
#  'Vienna Teng': ['ectofolk', 'melancholia', 'piano rock'],
#  'Rivers & Robots': ['ambient worship',
#   'christian uplift',
#   'deep ccm',
#   'world worship'],
#  'Aloe Blacc': ['pop soul', 'r&b'],
#  'Zac Brown Band': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Mieka Pauley': [],
#  "The Wailin' Jennys": ['ectofolk',
#   'folk',
#   'manitoba indie',
#   'progressive bluegrass',
#   "women's music"],
#  'Flannel Graph': ['indiecoustica'],
#  'ZEE MACHINE': [],
#  'Electric Light Orchestra': ['album rock',
#   'art rock',
#   'beatlesque',
#   'classic rock',
#   'glam rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  'Vacationer': ['philly indie', 'shimmer pop'],
#  'Linked Horizon': ['anime', 'otacore'],
#  'Alison Krauss': ['bluegrass', 'folk', 'progressive bluegrass'],
#  'John Denver': ['classic country pop',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'singer-songwriter',
#   'soft rock'],
#  'Langhorne Slim': ['anti-folk',
#   'indie folk',
#   'modern folk rock',
#   'new americana',
#   'stomp and holler'],
#  'Run River North': ['stomp and holler'],
#  'Lake Street Dive': ['boston rock', 'indie folk', 'new americana'],
#  'Penny and Sparrow': ['acoustic pop',
#   'indie folk',
#   'indiecoustica',
#   'stomp and flutter',
#   'stomp and holler'],
#  'Ashe': ['alt z'],
#  'Ben Kessler': ['gen z singer-songwriter'],
#  'boygenius': ['indie pop'],
#  'Lucy Dacus': ['chamber pop', 'indie pop'],
#  'Samia': ['indie pop'],
#  'quinnie': ['bedroom pop', 'indie pop'],
#  'Matilda Mann': ['british singer-songwriter',
#   'indie pop',
#   'modern indie folk'],
#  'Kevin Atwater': [],
#  'MUNA': ['indie pop', 'indie poptimism', 'la pop', 'metropopolis'],
#  'Tommy Lefroy': ['indie pop', 'modern indie folk'],
#  'Reneé Rapp': ['alt z'],
#  'Jensen McRae': ['gen z singer-songwriter'],
#  'Sammy Rae & The Friends': ['nyc pop'],
#  'Catie Turner': ['alt z', 'gen z singer-songwriter'],
#  'King Princess': ['alt z', 'indie pop', 'nyc pop'],
#  'Sabrina Carpenter': ['pop'],
#  'Sophie Holohan': [],
#  'Ryan Beatty': ['bedroom soul'],
#  'girl in red': ['bedroom pop', 'indie pop', 'norwegian indie', 'pov: indie'],
#  'Conan Gray': ['bedroom pop', 'pop', 'pov: indie'],
#  'Lennon Stella': ['alt z', 'canadian pop', 'uk pop'],
#  'Stephen Sanchez': ['gen z singer-songwriter'],
#  'Lilacs.': [],
#  'Suki Waterhouse': ['indie pop'],
#  'Michal Leah': [],
#  'Orla Gartland': ['indie pop', 'irish pop'],
#  'Maggie Rogers': ['indie pop'],
#  'Emily James': ['singer-songwriter pop'],
#  'FINNEAS': ['alt z', 'la indie', 'pop', 'pov: indie'],
#  'Sophie May': [],
#  'Olive Klug': ['gen z singer-songwriter'],
#  'Holly Humberstone': ['alt z',
#   'indie pop',
#   'modern alternative pop',
#   'uk pop'],
#  'Jordy Searcy': ['indiecoustica'],
#  'Zeph': ['gen z singer-songwriter'],
#  'Tiny Habits': [],
#  'Maude Latour': ['alt z', 'indie pop', 'nyc pop'],
#  'Grace Enger': [],
#  'Eloise': ['bedroom soul'],
#  'Noah Floersch': [],
#  'Delaney Bailey': ['gen z singer-songwriter'],
#  'Trousdale': ['modern indie folk'],
#  'Gatlin': ['modern alternative pop'],
#  'Taylor Bickett': ['alt z'],
#  'Madi Diaz': ['acoustic pop'],
#  'Del Water Gap': ['deep new americana', 'indie pop', 'pov: indie'],
#  'Ella Jane': ['alt z', 'gen z singer-songwriter', 'modern indie pop'],
#  'Carol Ades': ['gen z singer-songwriter'],
#  'Isabel Pless': ['gen z singer-songwriter'],
#  'Gracie Abrams': ['alt z'],
#  'Rachel Chinouriri': ['uk pop'],
#  'BabyJake': ['singer-songwriter pop'],
#  'Claire Rosinkranz': ['alt z', 'modern indie pop'],
#  'Griff': ['uk pop'],
#  'Thomas Headon': ['modern indie pop'],
#  'Jonah Kagen': ['singer-songwriter pop'],
#  'Paris Paloma': ['singer-songwriter pop'],
#  'Novo Amor': ['ambient folk',
#   'indie anthem-folk',
#   'indie folk',
#   'modern indie folk'],
#  'Brenn!': ['singer-songwriter pop'],
#  'Hazlett': ['brisbane indie', 'modern indie folk'],
#  'Wild Rivers': ['folk-pop'],
#  'The Band CAMINO': ['hopebeat', 'pov: indie'],
#  'Tori Kelly': ['pop', 'post-teen pop'],
#  'Drew Holcomb & the Neighbors': ['acoustic pop', 'stomp and holler'],
#  'The Lumineers': ['folk-pop', 'modern rock', 'stomp and holler'],
#  'Aidan Bissett': ['gen z singer-songwriter'],
#  'OneRepublic': ['piano rock', 'pop'],
#  'Wrabel': ['alt z', 'indie poptimism'],
#  'Zach Seabaugh': ['singer-songwriter pop'],
#  'Lawrence': ['nyc pop', 'retro soul'],
#  'The Head and the Heart': ['folk-pop', 'seattle indie', 'stomp and holler'],
#  'John Vincent III': ['modern indie folk'],
#  'Gregory Alan Isakov': ['indie folk',
#   'pop folk',
#   'stomp and flutter',
#   'stomp and holler'],
#  'Mt. Joy': ['pov: indie', 'stomp and holler'],
#  'Katie Lynne Sharbaugh': [],
#  'Henrik': [],
#  'Vincent Lima': [],
#  'Wilderado': ['indie folk', 'stomp and holler'],
#  'Mon RovÎa': [],
#  'Hans Williams': [],
#  'Surfaces': ['bedroom soul'],
#  'Josiah and the Bonnevilles': ['modern folk rock', 'stomp and holler'],
#  'Chance Peña': ['singer-songwriter pop'],
#  'Madeline the Person': ['gen z singer-songwriter'],
#  'Joy Oladokun': ['black americana', 'la pop'],
#  'Matt Hansen': ['gen z singer-songwriter', 'singer-songwriter pop'],
#  'Olivia Dean': ['pop soul'],
#  'Bella Poarch': ['modern alternative pop'],
#  'Yoke Lore': ['nyc pop'],
#  'The Paper Kites': ['acoustic pop',
#   'australian indie folk',
#   'indie anthem-folk',
#   'indie folk',
#   'stomp and flutter',
#   'stomp and holler'],
#  'Morningsiders': ['folk-pop'],
#  'Yelle': ['alternative dance',
#   'electro-pop francais',
#   'electroclash',
#   'electropop',
#   'filter house',
#   'neo-synthpop',
#   'new rave'],
#  'Owl City': ['indietronica', 'pop'],
#  'Roses & Revolutions': ['bossbeat'],
#  'Fairground Saints': ['indiecoustica'],
#  'Trace Bundy': ['fingerstyle'],
#  'Dave Matthews Band': ['jam band', 'neo mellow', 'pop rock'],
#  "The Mowgli's": ['hopebeat',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'stomp and holler',
#   'stomp pop'],
#  'Jain': ['french pop'],
#  'Hayden Calnin': ['australian indie',
#   'folktronica',
#   'indie anthem-folk',
#   'indie folk',
#   'modern indie folk'],
#  'Mat Kearney': ['acoustic pop', 'neo mellow'],
#  'Blitzen Trapper': ['indie folk',
#   'modern folk rock',
#   'new americana',
#   'portland indie',
#   'stomp and holler'],
#  'James Vincent McMorrow': ['chamber pop',
#   'indie folk',
#   'irish singer-songwriter',
#   'stomp and holler'],
#  'Griz': ['glitch hop', 'jamtronica', 'jazztronica', 'livetronica'],
#  'Lianne La Havas': ['alternative r&b',
#   'british soul',
#   'indie soul',
#   'neo soul',
#   'pop soul',
#   'soul'],
#  'Sweet': ['album rock', 'glam rock', 'hard rock'],
#  'Johnny Orlando': ['boy pop',
#   'canadian pop',
#   'singer-songwriter pop',
#   'social media pop',
#   'teen pop'],
#  'EVE 6': ['alternative metal', 'pop rock', 'post-grunge'],
#  'Yuri': ['korean ost'],
#  'Janelle Monáe': ['afrofuturism',
#   'alternative r&b',
#   'atl hip hop',
#   'neo soul',
#   'r&b'],
#  'Ola Gjeilo': ['21st century classical', 'nordic contemporary classical'],
#  'NAYEON': ['k-pop'],
#  'Damien Rice': ['irish rock',
#   'irish singer-songwriter',
#   'neo mellow',
#   'singer-songwriter'],
#  'Walk the Moon': ['dance rock',
#   'modern alternative rock',
#   'modern rock',
#   'pop'],
#  'Jonas Brothers': ['boy band', 'pop'],
#  'twenty one pilots': ['modern rock', 'pop', 'pov: indie', 'rock'],
#  'TWICE': ['k-pop', 'k-pop girl group', 'pop'],
#  'Avi Kaplan': [],
#  'Lane 8': ['gauze pop', 'progressive house'],
#  'Sara Hartman': ['nyc pop'],
#  'Gungor': ['christian indie'],
#  'Porter Robinson': ['complextro',
#   'edm',
#   'electro house',
#   'pop dance',
#   'progressive electro house'],
#  'Ryn Weaver': ['electropop', 'indie poptimism'],
#  'Saint Motel': ['la indie',
#   'modern alternative rock',
#   'modern rock',
#   'pov: indie'],
#  'Radiohead': ['alternative rock',
#   'art rock',
#   'melancholia',
#   'oxford indie',
#   'permanent wave',
#   'rock'],
#  'Laura Bell Bundy': ['broadway', 'country dawn', 'show tunes'],
#  'BTS': ['k-pop', 'k-pop boy group', 'pop'],
#  'Lewis Capaldi': ['pop', 'uk pop'],
#  'Osei The Seventh': [],
#  'John Mark McMillan': ['christian uplift', 'deep ccm'],
#  'Josh Garrels': ['christian indie', 'indy indie', 'roots worship'],
#  'eleventyseven': ['alternative pop rock'],
#  'Jon Bryant': ['indiecoustica', 'modern indie folk'],
#  'Birdtalker': ['folk-pop', 'stomp and holler'],
#  'Birds of Chicago': ['black americana', 'new americana'],
#  'Louise': [],
#  'AC/DC': ['australian rock', 'hard rock', 'rock'],
#  'Moon Byul': ['k-pop'],
#  'The Hush Sound': ['baroque pop', 'chicago indie', 'piano rock'],
#  'Christopher Jackson': ['broadway', 'movie tunes', 'show tunes'],
#  'The Script': ['celtic rock', 'pop'],
#  'Rick Astley': ['new romantic',
#   'new wave pop',
#   'soft rock',
#   'sophisti-pop',
#   'synthpop'],
#  'Rend Collective': ['ccm', 'christian alternative rock', 'christian music'],
#  'Jump Little Children': ['south carolina indie'],
#  'MisterWives': ['indie poptimism', 'modern rock', 'nyc pop', 'shimmer pop'],
#  'Queen': ['classic rock', 'glam rock', 'rock'],
#  'Marianas Trench': ['canadian rock', 'neon pop punk', 'pixie'],
#  'K/DA': ['k-pop girl group'],
#  'The Vassar Devils': ['a cappella'],
#  'Portugal. The Man': ['indie rock',
#   'indietronica',
#   'modern alternative rock',
#   'modern rock'],
#  'Demi Lovato': ['pop', 'post-teen pop'],
#  'Death Cab for Cutie': ['alternative rock',
#   'chamber pop',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'seattle indie',
#   'washington indie'],
#  'Elephant Revival': ['laboratorio',
#   'new americana',
#   'progressive bluegrass',
#   'washboard'],
#  'Vocal Few': ['indiecoustica'],
#  'Kanye West': ['chicago rap', 'hip hop', 'rap'],
#  'Josh Ramsay': [],
#  'Watsky': ['abstract hip hop', 'indie pop rap', 'nerdcore'],
#  'The Chainsmokers': ['pop'],
#  'TAEYEON': ['k-pop'],
#  'Straight No Chaser': ['a cappella'],
#  'Illenium': ['edm', 'melodic dubstep', 'pop dance'],
#  'Andy Grammer': ['neo mellow', 'post-teen pop', 'viral pop'],
#  'Mike Shinoda': ['alternative hip hop'],
#  'Fleetwood Mac': ['album rock',
#   'classic rock',
#   'rock',
#   'soft rock',
#   'yacht rock'],
#  'Bee Gees': ['disco', 'mellow gold', 'soft rock'],
#  'EXO': ['k-pop', 'k-pop boy group'],
#  'Alex & Sierra': ['pop', 'post-teen pop'],
#  'Jacob Fox': [],
#  'Ben Platt': ['broadway', 'show tunes'],
#  'Little India': [],
#  'Nic D': ['singer-songwriter pop'],
#  'Pistols At Dawn': [],
#  'blink-182': ['alternative metal',
#   'modern rock',
#   'pop punk',
#   'punk',
#   'rock',
#   'socal pop punk'],
#  'Scott Labbe': [],
#  'Connor Price': ['singer-songwriter pop'],
#  'Angel Hill': [],
#  'Pacifica': [],
#  'David Francey': ['canadian celtic',
#   'canadian folk',
#   'canadian singer-songwriter'],
#  'The Lonely Heartstring Band': ['neo-traditional bluegrass',
#   'new england americana'],
#  'Sara Watkins': ['bluegrass',
#   'bluegrass gospel',
#   'ectofolk',
#   'folk',
#   'new americana',
#   'progressive bluegrass'],
#  'Vulfpeck': ['ann arbor indie', 'funk rock', 'instrumental funk'],
#  'rozzi': ['pop soul'],
#  'Nickel Creek': ['bluegrass',
#   'instrumental bluegrass',
#   'mandolin',
#   'progressive bluegrass'],
#  'The Duhks': ['banjo',
#   'canadian folk',
#   'manitoba indie',
#   'progressive bluegrass'],
#  'Daniel Tashian': [],
#  'Watchhouse': ['new americana',
#   'north carolina roots',
#   'progressive bluegrass',
#   'stomp and holler'],
#  'Amos Lee': ['acoustic pop', 'neo mellow', 'stomp and holler'],
#  'Ira Wolf': [],
#  'The Show Ponies': ['folk-pop', 'neo-traditional bluegrass'],
#  "I'm With Her": [],
#  'Natalie Hemby': ['country pop'],
#  'The Secret Sisters': ['ectofolk', 'folk', 'indie folk', 'new americana'],
#  'Erin McKeown': ['ectofolk', "women's music"],
#  'Abigail Lapell': ['canadian folk',
#   'canadian singer-songwriter',
#   'new americana'],
#  'The Stray Birds': ['lancaster pa indie',
#   'new americana',
#   'progressive bluegrass'],
#  'The Fretless': ['irish neo-traditional'],
#  'Della Mae': ['nashville singer-songwriter',
#   'neo-traditional bluegrass',
#   'progressive bluegrass'],
#  'Humbird': ['midwest americana'],
#  'Aesop Rock': ['abstract hip hop',
#   'alternative hip hop',
#   'conscious hip hop'],
#  'Wu-Tang Clan': ['east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'rap'],
#  'Bastille': ['metropopolis', 'modern rock', 'pop'],
#  'The Harmaleighs': ['folk-pop', 'pop folk'],
#  'Runnner': ['countrygaze', 'la indie', 'small room'],
#  'NEEDTOBREATHE': ['ccm',
#   'christian alternative rock',
#   'christian indie',
#   'christian music',
#   'folk-pop'],
#  'Jake Scott': ['indiecoustica', 'singer-songwriter pop'],
#  'Eric Hutchinson': ['acoustic pop', 'neo mellow'],
#  'The Hunts': ['folk-pop', 'hampton roads indie'],
#  'Harbor & Home': ['indiecoustica'],
#  'The National Parks': ['folk-pop', 'stomp and holler', 'utah indie'],
#  'The Ballroom Thieves': ['boston folk', 'folk-pop', 'new england americana'],
#  'Ben Rector': ['acoustic pop',
#   'indiecoustica',
#   'lds youth',
#   'neo mellow',
#   'piano rock'],
#  'Wild': ['indiecoustica'],
#  'Clouds And Thorns': ['modern indie folk'],
#  'Graham Colton': ['acoustic pop', 'folk-pop', 'okc indie'],
#  'Richy Mitch & The Coal Miners': ['modern folk rock'],
#  'The East Pointers': ['canadian celtic',
#   'canadian folk',
#   'folk-pop',
#   'pei indie'],
#  'LayUp': [],
#  'Bleachers': ['indie pop', 'indie poptimism', 'modern rock', 'pov: indie'],
#  'Oliver Hazard': ['stomp and holler'],
#  'Tophouse': ['montana roots'],
#  'Florence + the Machine': ['baroque pop',
#   'electropop',
#   'modern rock',
#   'uk alternative pop'],
#  'The Collection': ['indiecoustica'],
#  'Coin': ['pov: indie'],
#  'Rose Betts': [],
#  'Joseph': ['folk-pop'],
#  'Colony House': ['hopebeat', 'pov: indie'],
#  'Chxrlotte': ['fantasy'],
#  'The Score': ['modern alternative rock', 'pov: indie'],
#  'Hollow Coves': ['indie anthem-folk', 'indie folk', 'modern indie folk'],
#  'The Crane Wives': ['grand rapids indie', 'michigan indie', 'pov: indie'],
#  'The Foundations': ['bubblegum pop'],
#  'Brothers Osborne': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock',
#   'modern southern rock'],
#  'Phillip Phillips': ['folk-pop', 'neo mellow'],
#  'Nathaniel Rateliff & the Night Sweats': ['indie folk',
#   'modern blues rock',
#   'new americana',
#   'stomp and holler'],
#  'Tyler Hubbard': ['contemporary country', 'modern country pop'],
#  'Barenaked Ladies': ['canadian pop',
#   'canadian rock',
#   'pop rock',
#   'post-grunge'],
#  'The Wandering Hearts': ['british country', 'uk americana'],
#  'Darius Rucker': ['black americana',
#   'contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Cereus Bright': ['knoxville indie', 'stomp and holler'],
#  'Picture This': ['irish pop'],
#  'Take That': ['boy band', 'europop', 'talent show'],
#  'Sigrid': ['norwegian pop'],
#  'Betty Who': ['australian dance', 'dance pop', 'electropop', 'metropopolis'],
#  'Carly Rae Jepsen': ['canadian pop', 'dance pop', 'pop'],
#  'LÉON': ['corrido', 'musica mexicana', 'sad sierreno', 'sierreno'],
#  'Maisie Peters': ['alt z', 'uk pop'],
#  'Years & Years': ['dance pop', 'gauze pop', 'pop', 'uk pop'],
#  'Peter Gabriel': ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'new romantic',
#   'new wave',
#   'permanent wave',
#   'progressive rock',
#   'rock',
#   'singer-songwriter',
#   'soft rock',
#   'symphonic rock'],
#  'Ao': ['boston folk',
#   'ectofolk',
#   'folk',
#   'indie folk',
#   'new americana',
#   'progressive bluegrass'],
#  'Rise Against': ['alternative metal',
#   'chicago hardcore',
#   'chicago punk',
#   'hardcore punk',
#   'modern rock',
#   'pop punk',
#   'post-grunge',
#   'punk'],
#  'Stromae': ['belgian pop', 'g-house'],
#  'Camila Cabello': ['dance pop', 'pop'],
#  'Kara': ['k-pop', 'k-pop girl group'],
#  'Ryan Reynolds': [],
#  'The Killers': ['alternative rock',
#   'dance rock',
#   'modern rock',
#   'permanent wave',
#   'rock'],
#  'San Fermin': ['brooklyn indie', 'chamber pop'],
#  "Mark O'Connor": ['bluegrass fiddle', 'jazz violin', 'progressive bluegrass'],
#  'The Beatles': ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  'John Newman': ['dance pop'],
#  'King Charles': ['folk-pop', 'shimmer pop'],
#  'Compton McMurry': [],
#  'Hwasa': ['k-pop', 'korean talent show'],
#  'CeeLo Green': ['atl hip hop'],
#  'Maroon 5': ['pop'],
#  'Todrick Hall': ['strut'],
#  'DC Talk': ['ccm', 'christian alternative rock', 'christian music'],
#  'Macklemore & Ryan Lewis': ['pop rap', 'seattle hip hop'],
#  'HAIM': ['indietronica', 'metropopolis'],
#  'Daisy the Great': ['brooklyn indie'],
#  'Imagine Dragons': ['modern rock', 'pop', 'rock'],
#  'Coldplay': ['permanent wave', 'pop'],
#  'Wilder Woods': ['acoustic pop', 'indiecoustica'],
#  'Smallpools': ['hopebeat',
#   'indie poptimism',
#   'la indie',
#   'la pop',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'pov: indie'],
#  'Big Wild': ['vapor soul'],
#  'Fitz and the Tantrums': ['la indie',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'pov: indie'],
#  'Franz Ferdinand': ['alternative rock',
#   'dance rock',
#   'indie rock',
#   'modern rock',
#   'rock',
#   'scottish rock'],
#  'Bombadil': [],
#  'Thomas Rhett': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'CHVRCHES': ['indietronica', 'metropopolis', 'neo-synthpop', 'shimmer pop'],
#  'NOTD': ['pop dance', 'pop edm'],
#  'Ozuna': ['puerto rican pop', 'reggaeton', 'trap latino', 'urbano latino'],
#  'Eminem': ['detroit hip hop', 'hip hop', 'rap'],
#  'Linkin Park': ['alternative metal',
#   'nu metal',
#   'post-grunge',
#   'rap metal',
#   'rock'],
#  'The Offspring': ['alternative metal',
#   'permanent wave',
#   'post-grunge',
#   'punk',
#   'rock',
#   'skate punk',
#   'socal pop punk'],
#  'Blue Swede': ['classic swedish pop'],
#  'Earl St. Clair': [],
#  'Daði Freyr': ['icelandic pop', 'sunnlensk tonlist'],
#  'Will Ferrell': [],
#  'NF': ['hip hop', 'pop rap'],
#  'Call Security': ['indie rockism', 'rhode island indie'],
#  'League of Legends': ['speedrun', 'video game music'],
#  'Billie Eilish': ['art pop', 'electropop', 'pop'],
#  'Beach Avenue': [],
#  'AnnenMayKantereit': ['cologne indie', 'german singer-songwriter'],
#  'The Doobie Brothers': ['album rock',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'heartland rock',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock',
#   'yacht rock'],
#  'DJ Khaled': ['hip hop', 'miami hip hop', 'pop rap', 'rap'],
#  'Loud Luxury': ['edm', 'pop dance'],
#  'Ludovico Einaudi': ['compositional ambient', 'neo-classical'],
#  'Cody Ko': [],
#  'Petey': [],
#  'Chris Brown': ['pop rap', 'r&b', 'rap'],
#  'Jon Batiste': ['new orleans jazz'],
#  'Leikeli47': ['alternative r&b', 'escape room', 'trap queen'],
#  'FLO': ['baroque pop', 'electropop', 'modern rock', 'uk alternative pop'],
#  'Nezza': [],
#  'Deluxe': ['electro swing', 'french indie pop'],
#  'Anderson .Paak': ['escape room', 'hip hop', 'indie soul', 'neo soul'],
#  'Leon Bridges': ['modern blues', 'neo soul', 'soul'],
#  'Etta James': ['jazz blues',
#   'soul',
#   'soul blues',
#   'torch song',
#   'vocal jazz'],
#  'FLOYD WONDER': ['bossbeat'],
#  'Greyson Chance': ['post-teen pop', 'viral pop'],
#  'Sickick': ['bass trap'],
#  'Fall Out Boy': ['emo', 'modern rock', 'pop', 'pop punk', 'rock'],
#  'That Poppy': [],
#  'Mackeson': [],
#  'AJR': ['pov: indie'],
#  'Louis the Child': ['edm', 'electropop', 'indie poptimism'],
#  'Miette Hope': [],
#  'Gabe Fleck': [],
#  'Castlecomer': ['hopebeat', 'indie rockism', 'modern alternative rock'],
#  'Us The Duo': ['folk-pop', 'viral pop'],
#  'Dessa': ['abstract hip hop', 'hip pop', 'minnesota hip hop'],
#  'Karmin': ['post-teen pop', 'viral pop'],
#  'Adam Tell': ['future bass'],
#  'Ben Zaidi': ['folk-pop'],
#  'bohnes': ['dark r&b', 'rebel blues'],
#  'Bruno Mars': ['dance pop', 'pop'],
#  'Naaz': ['dutch pop'],
#  'Emily Blue': [],
#  'Weathers': ['pov: indie'],
#  'Lizzo': ['escape room', 'minnesota hip hop', 'pop', 'trap queen'],
#  'Lana Del Rey': ['art pop', 'pop'],
#  'Damian La Grange': [],
#  'Clans': [],
#  'Powers': ['indie poptimism', 'la pop'],
#  'Foxtrax': [],
#  'Niko+': [],
#  'Superfruit': [],
#  'Nick Wilson': ['indie anthem-folk'],
#  'AKMU': ['k-pop'],
#  'Muse': ['alternative rock', 'modern rock', 'permanent wave', 'rock'],
#  'Seraphine': [],
#  'Saint Chaos': ['bossbeat'],
#  'Devon Cole': ['singer-songwriter pop'],
#  'Radical Face': ['indie folk', 'jacksonville indie', 'stomp and holler'],
#  'MAMAMOO': ['k-pop', 'k-pop girl group'],
#  'Monica Martin': [],
#  'J. Maya': ['alt z'],
#  "Girls' Generation-Oh!GG": ['k-pop', 'k-pop girl group'],
#  'Red Velvet': ['k-pop', 'k-pop girl group'],
#  'BOL4': ['k-pop'],
#  'SHINee': ['k-pop', 'k-pop boy group'],
#  'BLACKPINK': ['k-pop', 'k-pop girl group', 'pop'],
#  'aespa': ['k-pop girl group'],
#  'NewJeans': ['k-pop', 'k-pop girl group'],
#  'The Revivalists': ['modern alternative rock'],
#  'Fruit Bats': ['chamber pop',
#   'indie folk',
#   'indie rock',
#   'new americana',
#   'stomp and holler'],
#  'S.G. Goodman': ['kentucky roots'],
#  'Northwest Stories': [],
#  'David Kushner': ['gen z singer-songwriter'],
#  'Anna Bates': [],
#  'Liz Cooper': ['deep new americana'],
#  'Bailen': [],
#  'Kane Brown': ['black americana',
#   'contemporary country',
#   'country',
#   'country road'],
#  'Bebe Rexha': ['dance pop', 'pop'],
#  'Lee Brice': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'David Nail': ['contemporary country', 'country road', 'modern country rock'],
#  'Chris Young': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'MAX': ['post-teen pop', 'singer-songwriter pop', 'teen pop', 'viral pop'],
#  'Boyce Avenue': ['acoustic cover', 'neo mellow', 'viral pop'],
#  'Kiddo': [],
#  'Shawn Mendes': ['canadian pop', 'pop', 'viral pop'],
#  'Shakey Graves': ['austin americana',
#   'austindie',
#   'indie folk',
#   'new americana',
#   'stomp and holler'],
#  'Ed Staal': [],
#  'Chinese Kitty': ['trap queen'],
#  'French Montana': ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  'American Authors': ['modern rock', 'pop rock'],
#  'Lauren Henderson': ['contemporary vocal jazz', 'jazz pop'],
#  'Alok': ['electro house',
#   'pop nacional',
#   'sertanejo universitario',
#   'slap house'],
#  'Robin Schulz': ['deep euro house',
#   'deep house',
#   'edm',
#   'german dance',
#   'pop dance',
#   'tropical house'],
#  'H.E.R.': ['r&b', 'rap'],
#  'Slumberkins': [],
#  'Ez Mil': ['pinoy trap'],
#  'Alonestar': [],
#  'TOMORROW X TOGETHER': ['k-pop', 'k-pop boy group'],
#  'Meduza': ['edm', 'pop dance', 'pop house', 'uk dance'],
#  'Emilie du Leslay': [],
#  'BoyWithUke': ['sad rap'],
#  'Latto': ['trap queen'],
#  'Elle King': ['modern blues rock'],
#  '440 Smitty': [],
#  'Aly & AJ': ['dance pop', 'girl group', 'post-teen pop'],
#  'Lido': ['norwegian pop', 'vapor twitch'],
#  'Fred again..': ['edm', 'house', 'stutter house'],
#  'Mitski': ['brooklyn indie', 'pov: indie'],
#  'Burna Boy': ['afrobeats',
#   'azontobeats',
#   'dancehall',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Aventura': [],
#  'Glass Animals': ['gauze pop',
#   'indietronica',
#   'modern rock',
#   'pov: indie',
#   'shiver pop'],
#  'Rex Orange County': ['bedroom pop'],
#  'Tai Verdes': ['modern indie pop', 'singer-songwriter pop'],
#  'Daryl Hall & John Oates': ['album rock',
#   'classic rock',
#   'heartland rock',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock',
#   'yacht rock'],
#  'Matchbox Twenty': ['neo mellow', 'pop rock', 'post-grunge'],
#  'Spacey Jane': ['australian indie rock',
#   'australian surf rock',
#   'fremantle indie',
#   'perth indie'],
#  'Sebastian Yatra': ['colombian pop',
#   'latin pop',
#   'latin viral pop',
#   'reggaeton',
#   'reggaeton colombiano',
#   'urbano latino'],
#  'Kacey Musgraves': ['classic texas country',
#   'contemporary country',
#   'country dawn'],
#  'The Rions': ['australian indie rock', 'australian surf rock'],
#  'The Beaches': ['toronto indie'],
#  'Saweetie': ['cali rap', 'trap queen'],
#  'Monaleo': ['viral rap'],
#  'The Wldlfe': ['hopebeat', 'indy indie'],
#  'Lostboycrow': ['indie poptimism', 'indietronica'],
#  'Prentiss': [],
#  'Post Malone': ['dfw rap', 'melodic rap', 'pop', 'rap'],
#  'Naughty By Nature': ['east coast hip hop', 'hip hop', 'new jersey rap'],
#  'The Band': ['hopebeat', 'pov: indie'],
#  'LL Cool J': ['east coast hip hop',
#   'golden age hip hop',
#   'hip hop',
#   'old school hip hop',
#   'queens hip hop',
#   'rap'],
#  'Kandi': ['contemporary r&b', 'hip pop', 'r&b'],
#  'Memphis LK': [],
#  'The Diplomats': ['hardcore hip hop', 'harlem hip hop', 'southern hip hop'],
#  'Nicky Youre': ['singer-songwriter pop'],
#  'Stacey Ryan': [],
#  'Morgan Wallen': ['contemporary country'],
#  'The Brummies': ['alabama indie'],
#  'Kaskade': ['edm',
#   'electro house',
#   'pop dance',
#   'progressive electro house',
#   'progressive house',
#   'vocal house'],
#  'Daddy Yankee': ['latin hip hop',
#   'reggaeton',
#   'trap latino',
#   'urbano latino'],
#  'Drama': ['indie soul'],
#  'Rainbow Kitten Surprise': ['pov: indie'],
#  'Jungle': ['indie soul', 'indietronica', 'uk contemporary r&b'],
#  'Elovay': [],
#  'Jim-E Stack': [],
#  'Bomb比尔': ['chinese viral pop'],
#  'Space X': ['chinese viral pop'],
#  'Libianca': ['afrobeats'],
#  'IVE': ['italian hip hop'],
#  'Mura Masa': ['channel islands indie',
#   'hyperpop',
#   'indie soul',
#   'vapor soul'],
#  'Alan Gogoll': ['tassie indie'],
#  'Chris Lake': ['bass house',
#   'edm',
#   'electro house',
#   'house',
#   'melbourne bounce',
#   'pop dance',
#   'progressive house',
#   'tech house'],
#  'Tove Lo': ['metropopolis',
#   'pop',
#   'swedish electropop',
#   'swedish pop',
#   'swedish synthpop'],
#  'Normani': ['pop', 'r&b'],
#  'Dwayne Johnson': ['meme'],
#  'Sade': ['british soul', 'sophisti-pop'],
#  'Miley Cyrus': ['pop'],
#  'JVKE': ['modern indie pop', 'pov: indie', 'singer-songwriter pop'],
#  'Laufey': ['gen z singer-songwriter'],
#  'Justine Skye': ['pop r&b', 'r&b'],
#  'Coi Leray': ['new jersey underground rap', 'trap queen'],
#  'S3BZS': [],
#  'Kali Uchis': ['colombian pop'],
#  'New West': ['toronto indie'],
#  'Tyler the Creator': ['hip hop', 'rap'],
#  'd4vd': ['bedroom pop', 'bedroom r&b'],
#  'Dave': ['jam band', 'neo mellow', 'pop rock'],
#  'Troye Sivan': ['australian pop', 'pop', 'viral pop'],
#  'Doechii': ['alternative r&b'],
#  'TroyBoi': ['bass trap', 'electronic trap'],
#  'XYLØ': ['alt z', 'indie poptimism', 'la pop'],
#  'Chase Rice': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Kelly Clarkson': ['dance pop', 'pop', 'talent show'],
#  'Luke Bryan': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Maren Morris': ['classic texas country', 'contemporary country'],
#  'Jason Aldean': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Jana Kramer': ['contemporary country',
#   'country',
#   'country dawn',
#   'country road'],
#  'Eli Young Band': ['classic texas country',
#   'contemporary country',
#   'country',
#   'country road',
#   'heartland rock',
#   'modern country rock'],
#  'Blake Shelton': ['classic oklahoma country',
#   'contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Hunter Hayes': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Kip Moore': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Sam Hunt': ['contemporary country',
#   'country',
#   'country pop',
#   'modern country rock'],
#  'Finding Hope': ['chill r&b'],
#  'Autoheart': ['hopebeat', 'pov: indie'],
#  'Will Jay': ['la pop'],
#  'Clean Bandit': ['pop', 'uk dance', 'uk funky'],
#  'Infected Mushroom': ['psychedelic trance'],
#  'Zac Brown': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'half•alive': ['alt z', 'pov: indie'],
#  'Fizz': [],
#  'Will Smith': ['hip hop', 'pop rap'],
#  'Michael Bublé': ['adult standards', 'canadian pop', 'jazz pop', 'lounge'],
#  'Kansas': ['album rock',
#   'classic rock',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock'],
#  'Lea Salonga': ['movie tunes', 'tagalog worship'],
#  'John Legend': ['neo soul', 'pop', 'pop soul', 'urban contemporary'],
#  '叶琼琳': ['chinese viral pop'],
#  'Home Free': ['a cappella'],
#  'Bray Brown': [],
#  'Tiësto': ['big room',
#   'brostep',
#   'dutch edm',
#   'edm',
#   'house',
#   'pop dance',
#   'slap house',
#   'trance'],
#  'Hedegaard': ['danish electronic', 'scandipop'],
#  'Ellery Bonham': [],
#  'Pink Sweat$': ['bedroom soul'],
#  'Brandy': ['contemporary country', 'queer country'],
#  'whatever mike': ['neo r&b', 'nyc pop'],
#  'Osis': [],
#  'Aiza': ['burundian pop', 'high vibe'],
#  'Groove Theory': ['contemporary r&b', 'new jack swing'],
#  'Sofi Tukker': ['edm'],
#  'Teddy Pendergrass': ['classic soul',
#   'funk',
#   'motown',
#   'philly soul',
#   'quiet storm',
#   'soul',
#   'urban contemporary'],
#  'Spritely': ['acoustic chill'],
#  'Alicia Gianni': [],
#  'Two Feet': ['indie poptimism', 'modern rock'],
#  'Meghan Trainor': ['hip pop', 'pop'],
#  'Theo Tams': ['canadian pop'],
#  'D.B. Ricapito': [],
#  'Upsahl': ['alt z', 'modern indie pop'],
#  'Beth Hart Joe Bonamassa': [],
#  'Jeremy Zucker': ['alt z', 'electropop', 'pop'],
#  'Blake Rose': ['australian electropop', 'singer-songwriter pop'],
#  'Nat King Cole': ['adult standards',
#   'easy listening',
#   'lounge',
#   'soul',
#   'swing',
#   'vocal jazz'],
#  'Jesse McCartney': ['dance pop', 'pop', 'post-teen pop'],
#  'Ruth B.': ['alt z', 'canadian contemporary r&b', 'canadian pop', 'pop'],
#  'Phoenix': ['alternative dance',
#   'indie rock',
#   'modern rock',
#   'neo-synthpop',
#   'new rave',
#   'rock independant francais',
#   'shimmer pop'],
#  'Capital Cities': ['metropopolis', 'modern rock'],
#  'The Avalanches': ['australian alternative rock',
#   'australian dance',
#   'collage pop',
#   'electronica',
#   'indietronica',
#   'new rave',
#   'psychedelic hip hop'],
#  'The Whitest Boy Alive': ['alternative dance', 'indietronica', 'new rave'],
#  'Gorillaz': ['alternative hip hop', 'modern rock', 'rock'],
#  'M83': ['french shoegaze',
#   'french synthpop',
#   'indietronica',
#   'metropopolis',
#   'neo-synthpop'],
#  'C2C': ['bow pop', 'cello', 'string duo'],
#  'Madeon': ['complextro',
#   'edm',
#   'electro house',
#   'electropop',
#   'filter house',
#   'nantes indie',
#   'pop dance'],
#  'The Black Keys': ['alternative rock',
#   'blues rock',
#   'garage rock',
#   'indie rock',
#   'indietronica',
#   'modern blues rock',
#   'modern rock',
#   'punk blues',
#   'rock',
#   'roots rock'],
#  'Metronomy': ['alternative dance',
#   'electronica',
#   'french indie pop',
#   'indietronica',
#   'neo-synthpop',
#   'new rave',
#   'socal pop punk'],
#  'Pharrell Williams': ['dance pop', 'pop'],
#  'The xx': ['downtempo', 'dream pop', 'indietronica'],
#  'Breakbot': ['filter house', 'funktronica', 'nu disco'],
#  'Parcels': ['aussietronica', 'indie soul'],
#  'Thundercat': ['afrofuturism', 'escape room', 'indie soul'],
#  'KIDS SEE GHOSTS': ['rap'],
#  'The Civil Wars': ['acoustic pop',
#   'indie folk',
#   'neo mellow',
#   'new americana',
#   'stomp and holler'],
#  'Marc Scibilia': ['acoustic pop', 'indiecoustica'],
#  'Plàsi': ['modern indie folk', 'swedish folk pop', 'swedish indie folk'],
#  'Blind Pilot': ['indie folk', 'portland indie', 'stomp and holler'],
#  'Wild Child': ['austin americana',
#   'austindie',
#   'folk-pop',
#   'indie folk',
#   'stomp and holler'],
#  'Aaron Espe': ['modern indie folk', 'stomp and flutter'],
#  'Twin Forks': ['folk-pop'],
#  'The Postal Service': ['chamber pop',
#   'indie rock',
#   'indietronica',
#   'seattle indie'],
#  'Toploader': ['british alternative rock'],
#  'He Is We': ['alternative pop rock',
#   'neon pop punk',
#   'pixie',
#   'washington indie'],
#  'Yo-Yo Ma': ['chamber ensemble', 'classical cello', 'classical performance'],
#  'All That Jazz': [],
#  'Seafret': ['folk-pop'],
#  'James Arthur': ['pop', 'talent show', 'uk pop'],
#  'Roo Panes': ['british singer-songwriter',
#   'indie anthem-folk',
#   'indie folk',
#   'stomp and holler'],
#  'Stephen Puth': [],
#  'The Banker Boys': [],
#  'Frank Walker': [],
#  'The Aces': ['alt z', 'indie pop', 'indie poptimism', 'uk pop'],
#  'Elio': ['alt z', 'electropop'],
#  'Mallrat': ['aussietronica', 'australian indie', 'brisbane indie'],
#  'Pearly Drops': ['dark synthpop'],
#  'Miya Folick': ['indie pop', 'la indie'],
#  'Planet 1999': ['escape room', 'hyperpop'],
#  'Remi Wolf': ['indie pop', 'modern alternative pop'],
#  'BANKS': ['art pop',
#   'electropop',
#   'indie poptimism',
#   'indietronica',
#   'shimmer pop'],
#  'Julia Jacklin': ['chamber pop', 'countrygaze', 'indie pop', 'sydney indie'],
#  'Rina Sawayama': ['art pop', 'electropop', 'escape room', 'indie pop'],
#  'Young Fathers': ['abstract hip hop',
#   'art pop',
#   'chamber psych',
#   'scottish hip hop'],
#  'Grimes': ['art pop',
#   'canadian electropop',
#   'grave wave',
#   'indietronica',
#   'metropopolis',
#   'neo-synthpop'],
#  'Arlo Parks': ['indie pop', 'indie soul', 'uk contemporary r&b'],
#  'Claud': ['bedroom pop', 'indie pop'],
#  'The Japanese House': ['indie pop',
#   'indietronica',
#   'modern dream pop',
#   'pov: indie',
#   'vapor soul'],
#  'Japanese Breakfast': ['art pop',
#   'eugene indie',
#   'indie pop',
#   'indie rock',
#   'philly indie'],
#  'Alvvays': ['art pop',
#   'chamber pop',
#   'dream pop',
#   'dreamo',
#   'indie pop',
#   'indie rock',
#   'noise pop',
#   'shoegaze',
#   'toronto indie'],
#  'Grace Ives': ['experimental indie'],
#  'Tanukichan': ['oakland indie'],
#  'Tennis': ['art pop',
#   'chamber pop',
#   'chillwave',
#   'denver indie',
#   'indie pop',
#   'indie rock',
#   'indie surf',
#   'shimmer pop'],
#  'Skullcrusher': ['countrygaze', 'small room'],
#  'Jay Som': ['art pop',
#   'bay area indie',
#   'bubblegrunge',
#   'indie pop',
#   'oakland indie',
#   'small room'],
#  'ODESZA': ['chillwave', 'edm', 'indietronica'],
#  'Okay Kaya': ['art pop'],
#  'Barrie': ['brooklyn indie', 'indie pop'],
#  'DNCE': ['dance pop', 'pop'],
#  'Dennis Lloyd': ['israeli pop'],
#  'Zedd': ['complextro', 'edm', 'german techno', 'pop', 'pop dance'],
#  'Lil Nas X': ['lgbtq+ hip hop'],
#  'Jessie J': ['dance pop', 'pop'],
#  'Fergie': ['dance pop', 'pop'],
#  'Fifth Harmony': ['girl group', 'pop', 'talent show'],
#  'Ombre2Choc Nation': ['new york drill'],
#  'Fort Minor': ['rap rock'],
#  'The Wilder Blue': ['red dirt', 'texas country'],
#  'Cody Fry': ['indiecoustica'],
#  'Glee Cast': ['glee club', 'post-teen pop'],
#  're:plus': ['bossbeat'],
#  'Stephen Schwartz': ['broadway', 'show tunes'],
#  'Weird Al Yankovic': ['comedy rock', 'comic', 'parody'],
#  'Josh Turner': ['contemporary country', 'country', 'country road'],
#  'Noah Guthrie': [],
#  "Aoife O'Donovan": ['boston folk',
#   'ectofolk',
#   'folk',
#   'indie folk',
#   'new americana',
#   'progressive bluegrass'],
#  'Kotaro Oshio': ['japanese guitar'],
#  'Ingrid Michaelson': ['acoustic pop', 'ectofolk', 'lilith', 'neo mellow'],
#  'Brandon Seibert': [],
#  'Ella Fitzgerald': ['adult standards',
#   'jazz',
#   'jazz blues',
#   'soul',
#   'swing',
#   'vocal jazz'],
#  'George Michael': ['new wave pop'],
#  'The Gray Havens': ['christian uplift', 'roots worship'],
#  'SBTRKT': ['electronica', 'future garage', 'indie soul', 'indietronica'],
#  'Audio Adrenaline': ['ccm', 'christian alternative rock', 'christian music'],
#  'Renée Elise Goldsberry': ['broadway', 'show tunes'],
#  'Julia Harriman': [],
#  'William Fitzsimmons': ['acoustic pop', 'indie folk'],
#  'Jim Yosef': ['gaming edm'],
#  'Edvard Grieg': ['classical', 'late romantic era', 'norwegian classical'],
#  'Chris Thile': ['bluegrass',
#   'classical mandolin',
#   'instrumental bluegrass',
#   'mandolin',
#   'progressive bluegrass'],
#  'Parachute': ['acoustic pop',
#   'charlottesville indie',
#   'neo mellow',
#   'neon pop punk',
#   'pop rock',
#   'viral pop'],
#  'Laura Marling': ['british folk',
#   'british singer-songwriter',
#   'chamber pop',
#   'singer-songwriter'],
#  'LaFrantz': [],
#  'Matt Corby': ['australian indie'],
#  'CHUNG HA': ['k-pop'],
#  'Tall Heights': ['boston folk', 'folk-pop'],
#  'Juanes': ['colombian pop', 'latin pop', 'mexican pop', 'rock en espanol'],
#  'Jesca Hoop': ['etherpop'],
#  'The Lonely Island': ['comedy rap', 'comic'],
#  'José González': ['chamber pop',
#   'gothenburg indie',
#   'indie folk',
#   'stomp and holler',
#   'swedish indie folk',
#   'swedish indie pop',
#   'swedish singer-songwriter'],
#  'MATOMA': ['pop dance', 'tropical house'],
#  'Cosmo Sheldrake': ['pov: indie', 'uk pop'],
#  'Bea Miller': ['alt z', 'pop', 'talent show'],
#  'Pentatonix': ['a cappella', 'viral pop'],
#  'St. Paul & The Broken Bones': ['retro soul'],
#  'Truslow': ['christian rock', 'indie rockism'],
#  'Chiaki Ishikawa': ['anime'],
#  'Sara Bareilles': ['acoustic pop',
#   'ectofolk',
#   'lilith',
#   'neo mellow',
#   'pop rock',
#   'post-teen pop'],
#  'The Fray': ['neo mellow', 'piano rock', 'pop', 'pop rock'],
#  'Casting Crowns': ['ccm', 'christian alternative rock', 'christian music'],
#  'Two Worlds': ['channel pop', 'viral pop'],
#  'The Family Crest': ['bay area indie', 'chamber pop'],
#  'The Dead South': ['saskatchewan indie'],
#  'Harry Chapin': ['classic rock',
#   'country rock',
#   'folk',
#   'folk rock',
#   'heartland rock',
#   'mellow gold',
#   'singer-songwriter',
#   'soft rock'],
#  "Martin O'Donnell": ['scorecore', 'video game music'],
#  'Griffin House': ['acoustic pop'],
#  'Macklemore': ['pop rap', 'seattle hip hop'],
#  'Samsa': ['lo-fi rap'],
#  'Jerry Douglas': ['bluegrass',
#   'instrumental bluegrass',
#   'jig and reel',
#   'progressive bluegrass'],
#  'Ivory Layne': ['nashville singer-songwriter'],
#  'Nathan Fillion': [],
#  'Kennedy': ['folk-pop', 'irish pop', 'uk pop'],
#  'Marty Grimes': ['cali rap', 'deep underground hip hop', 'indie pop rap'],
#  'Lights Follow': [],
#  'Imogen Heap': ['etherpop', 'metropopolis'],
#  'Chloe Adams': ['alt z'],
#  'Crooked Still': ['banjo',
#   'bluegrass gospel',
#   'new england americana',
#   'progressive bluegrass'],
#  'David Guetta': ['big room', 'dance pop', 'edm', 'pop', 'pop dance'],
#  'Peter Hollens': ['fantasy'],
#  'KONGOS': ['modern alternative rock',
#   'modern blues rock',
#   'south african rock'],
#  'Thin Lizzy': ['album rock',
#   'blues rock',
#   'british blues',
#   'classic rock',
#   'glam metal',
#   'hard rock',
#   'irish rock',
#   'metal',
#   'rock'],
#  'Air Traffic Controller': ['folk-pop', 'hopebeat', 'shiver pop'],
#  'Justin Bieber': ['canadian pop', 'pop'],
#  'The Drawing Room': [],
#  'Hugh Jackman': ['hollywood', 'show tunes'],
#  'Switchfoot': ['ccm', 'christian alternative rock', 'christian music'],
#  'Mylène Farmer': ['chanson', 'french pop', 'french synthpop'],
#  'HRVY': ['pop'],
#  'Parov Stelar': ['balkan beats', 'downtempo', 'electro swing', 'nu jazz'],
#  'Sam Beam': ['chamber folk'],
#  'Panic! at the Disco': ['pop'],
#  'Beta Radio': ['indie folk',
#   'modern indie folk',
#   'stomp and flutter',
#   'stomp and holler'],
#  'inabakumori': [],
#  'Claude Debussy': ['classical', 'impressionism', 'post-romantic era'],
#  'Kyle Landry': [],
#  'Ehrling': ['saxophone house', 'tropical house'],
#  'Steven Curtis Chapman': ['ccm',
#   'christian alternative rock',
#   'christian music'],
#  'Raffi': ["canadian children's music", "children's folk", "children's music"],
#  'Cake': ['alternative rock', 'pop rock', 'post-grunge', 'sacramento indie'],
#  'Fink': ['indie folk'],
#  'Geoff Castellucci': [],
#  'Rufus Wainwright': ['canadian pop',
#   'chamber pop',
#   'melancholia',
#   'piano rock',
#   'singer-songwriter'],
#  'Big Boi': ['atl hip hop', 'dirty south rap', 'hip hop', 'southern hip hop'],
#  'Coyote Kisses': ['complextro', 'glitch hop'],
#  'Gillian Welch': ['alternative country',
#   'canadian singer-songwriter',
#   'folk',
#   'melancholia',
#   'nashville singer-songwriter',
#   'new americana',
#   'progressive bluegrass',
#   'singer-songwriter'],
#  'Georgi Kay': ['australian dance', 'perth indie'],
#  'Stelth Ulvang': [],
#  'Los Coast': ['austindie', 'synth funk'],
#  'annapantsu': ['otacore', 'pixel'],
#  'Jimmy Eat World': ['alternative metal',
#   'alternative rock',
#   'emo',
#   'modern power pop',
#   'modern rock',
#   'neon pop punk',
#   'pop punk',
#   'pop rock',
#   'post-grunge',
#   'punk',
#   'rock'],
#  'Coleman Hell': ['canadian pop', 'indie poptimism'],
#  'Tommee Profitt': ['anthem worship', 'bossbeat'],
#  'Jeff Buckley': ['melancholia', 'permanent wave', 'singer-songwriter'],
#  'Warpaint': ['alternative dance',
#   'art pop',
#   'chamber pop',
#   'dance-punk',
#   'dream pop',
#   'electronica',
#   'indie rock',
#   'la indie',
#   'modern dream pop',
#   'neo-synthpop',
#   'new rave',
#   'shimmer pop'],
#  'Ashley Monroe': ['contemporary country', 'country dawn', 'kentucky roots'],
#  'Hozier': ['irish singer-songwriter', 'modern rock', 'pov: indie'],
#  'Me and My Friends': ['afrobeat fusion'],
#  'Bishop Briggs': ['modern alternative rock'],
#  'Kaleo': ['icelandic indie', 'icelandic rock', 'modern alternative rock'],
#  'Journey': ['album rock',
#   'classic rock',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'rock',
#   'soft rock'],
#  'Junior Senior': ['danish pop'],
#  'Michael Jackson': ['r&b', 'soul'],
#  'Fountains of Wayne': ['pop rock', 'power pop'],
#  'Toto': ['album rock',
#   'classic rock',
#   'hard rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'yacht rock'],
#  'Grits': ['christian hip hop'],
#  'a-ha': ['new romantic',
#   'new wave',
#   'new wave pop',
#   'permanent wave',
#   'synthpop'],
#  'Bob Seger': ['album rock',
#   'classic rock',
#   'country rock',
#   'detroit rock',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock'],
#  'Counting Crows': ['neo mellow', 'pop rock', 'post-grunge', 'rock'],
#  'Paul Simon': ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'permanent wave',
#   'rock',
#   'singer-songwriter',
#   'soft rock'],
#  'Rick Springfield': ['album rock',
#   'australian rock',
#   'classic rock',
#   'glam metal',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'new romantic',
#   'new wave pop',
#   'soft rock',
#   'yacht rock'],
#  'Mark Ronson': ['pop soul'],
#  'Norman Greenbaum': ['classic rock'],
#  'The Romantics': ['album rock',
#   'classic rock',
#   'heartland rock',
#   'mellow gold',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'power pop',
#   'soft rock'],
#  'Neil Diamond': ['adult standards',
#   'brill building pop',
#   'folk rock',
#   'heartland rock',
#   'mellow gold',
#   'singer-songwriter',
#   'soft rock',
#   'yacht rock'],
#  'Jason Mraz': ['acoustic pop', 'dance pop', 'neo mellow', 'pop'],
#  'Frankie Valli & the Four Seasons': ['adult standards',
#   'bubblegum pop',
#   'doo-wop',
#   'lounge',
#   'northern soul',
#   'rock-and-roll',
#   'rockabilly'],
#  'Dexys Midnight Runners': ['new romantic', 'new wave', 'new wave pop'],
#  'Katrina & The Waves': ['new wave pop'],
#  'Van Morrison': ['classic rock',
#   'folk',
#   'folk rock',
#   'heartland rock',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock'],
#  'The Temptations': ['memphis soul', 'motown', 'soul'],
#  'fun.': ['baroque pop', 'metropopolis'],
#  'Jackie Wilson': ['chicago soul',
#   'classic soul',
#   'quiet storm',
#   'rock-and-roll',
#   'soul'],
#  'The Jackson 5': ['motown', 'soul'],
#  'Faye Webster': ['atlanta indie', 'indie pop'],
#  'Mae Stephens': ['singer-songwriter pop'],
#  'Oxlade': ['afrobeats', 'nigerian pop'],
#  'The Blasting Company': ['chamber folk'],
#  'Andrew Huang': ['canadian electronic'],
#  'Louie Zong': ['pov: indie', 'weirdcore'],
#  'Young Rising Sons': ['folk-pop', 'hopebeat'],
#  'Silver Cup': [],
#  'Dylan Flynn and the Dead Poets': ['limerick indie'],
#  'Dayglow': ['austindie', 'indie rock', 'pov: indie'],
#  'Sophia Anne Caruso': ['broadway', 'show tunes'],
#  'Matt Dahan': [],
#  'Magic Sugar Coffee': [],
#  'Swim': [],
#  'Vanisa Khamkhosy': [],
#  'John Mark Nelson': ['minneapolis indie'],
#  'Wendlo': [],
#  'Ryan Nealon': [],
#  'Kelechi': [],
#  'James and the Shame': [],
#  'Eva Westphal': ['gen z singer-songwriter'],
#  'Annika Bennett': ['nashville singer-songwriter'],
#  'Ben Folds': ['permanent wave', 'piano rock'],
#  'Jukebox the Ghost': ['modern rock', 'piano rock', 'pov: indie'],
#  'Sawyer': [],
#  'saturn 17': [],
#  'Naethan Apollo': ['pov: indie'],
#  'Ricky Montgomery': ['la indie', 'pop', 'pov: indie'],
#  'Chrissy Chlapecka': [],
#  'Xana': ['alt z'],
#  'rainbow frog biscuits': ['gen z singer-songwriter'],
#  'Maty Noyes': ['alt z'],
#  'Carr': ['movie tunes'],
#  'Scrawny': [],
#  'Thomas Newman': ['orchestral soundtrack', 'soundtrack'],
#  'Foster the People': ['indietronica',
#   'modern alternative rock',
#   'modern rock',
#   'rock'],
#  'Green Day': ['modern rock', 'permanent wave', 'punk', 'rock'],
#  'Guster': ['boston rock'],
#  'Fastball': ['pop rock', 'post-grunge'],
#  'Sugarcult': ['neon pop punk', 'pop punk', 'screamo'],
#  'Third Eye Blind': ['alternative metal',
#   'alternative rock',
#   'pop rock',
#   'post-grunge'],
#  'Yellowcard': ['alternative metal',
#   'pop punk',
#   'post-grunge',
#   'socal pop punk'],
#  'Hootie & The Blowfish': ['heartland rock', 'pop rock', 'post-grunge'],
#  'Nine Days': ['pop rock'],
#  'Johnny Cash': ['arkansas country', 'outlaw country', 'rock'],
#  'Ellie Goulding': ['indietronica', 'metropopolis', 'pop', 'uk pop'],
#  'FM Static': ['canadian ccm', 'canadian pop punk', 'christian punk'],
#  'deadmau5': ['canadian electronic',
#   'complextro',
#   'edm',
#   'electro house',
#   'pop dance',
#   'progressive house'],
#  'Umitaro Abe': ['anime score', 'japanese piano'],
#  'Jóhann Jóhannsson': ['compositional ambient',
#   'experimental classical',
#   'icelandic classical',
#   'icelandic experimental',
#   'nordic soundtrack',
#   'soundtrack'],
#  'Josh Gad': ['movie tunes'],
#  'Justin Hurwitz': ['hollywood', 'movie tunes'],
#  'Max Richter': ['compositional ambient', 'post-minimalism'],
#  'Austin Farwell': ['ambient lo-fi'],
#  'Sleeping at Last': ['acoustic pop', 'ambient worship', 'chamber pop'],
#  'Keala Settle': ['broadway', 'hollywood', 'show tunes'],
#  'Michelle Williams': ['gospel r&b', 'hip pop'],
#  'Alfonso De Vilallonga': ['latin soundtrack'],
#  'Emma Stone': ['hollywood'],
#  'Ryan Gosling': ['hollywood'],
#  'Rascal Flatts': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Donny Osmond': ['bubblegum pop', 'movie tunes'],
#  'Young the Giant': ['indietronica',
#   'modern alternative rock',
#   'modern rock',
#   'pov: indie',
#   'stomp and holler'],
#  'Walk Off the Earth': ['canadian rock', 'pop rock'],
#  'Sir Rosevelt': [],
#  'Glin': ['scottish folk'],
#  'Nohe & Sus Santos': [],
#  'Rachel Platten': ['post-teen pop', 'viral pop'],
#  'The Dip': ['retro soul'],
#  'French 79': ['french indie pop', 'french indietronica'],
#  'Alice Merton': [],
#  'Fulton Lee': ['pop soul'],
#  'Adib Sin': [],
#  'Eric Nam': ['k-pop'],
#  'mxmtoon': ['alt z', 'bedroom pop', 'indie pop', 'pov: indie'],
#  'Scott Hoying': [],
#  'RADWIMPS': ['j-pop', 'j-rock', 'japanese emo', 'visual kei'],
#  'The Beach Boys': ['baroque pop',
#   'classic rock',
#   'folk rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'sunshine pop'],
#  'Harry Styles': ['pop'],
#  'Walker Hayes': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Cole Swindell': ['contemporary country',
#   'country',
#   'country road',
#   'modern country rock'],
#  'Bizzy': ['singer-songwriter pop'],
#  'Chappell Roan': ['indie pop', 'springfield mo indie'],
#  'Stellar': ['social media pop'],
#  '5 Seconds of Summer': ['boy band', 'pop'],
#  'bbno$': ['canadian hip hop', 'dark trap', 'meme rap'],
#  'Mokita': ['chill pop', 'singer-songwriter pop'],
#  'Elley Duhé': ['alt z'],
#  'Grant': ['future bass'],
#  'Arctic Monkeys': ['garage rock',
#   'modern rock',
#   'permanent wave',
#   'rock',
#   'sheffield indie'],
#  'The Beths': ['auckland indie',
#   'bubblegrunge',
#   'indie rock',
#   'kiwi rock',
#   'modern power pop',
#   'nz indie'],
#  'The White Stripes': ['alternative rock',
#   'blues rock',
#   'detroit rock',
#   'garage rock',
#   'modern blues rock',
#   'permanent wave',
#   'punk blues',
#   'rock'],
#  "Guns N' Roses": ['glam metal', 'hard rock', 'rock'],
#  'Lynyrd Skynyrd': ['album rock',
#   'classic rock',
#   'hard rock',
#   'rock',
#   'southern rock'],
#  'Armin van Buuren': ['dutch house',
#   'dutch trance',
#   'edm',
#   'pop dance',
#   'progressive house',
#   'trance'],
#  'John Michael Howell': ['singer-songwriter pop'],
#  'Youha': ['k-indie'],
#  'Loote': ['alt z', 'nyc pop'],
#  'Diana Krall': ['contemporary vocal jazz', 'jazz pop', 'vocal jazz'],
#  'Varian': ['experimental pop'],
#  'Andrew Lloyd Webber': ['broadway', 'west end'],
#  'Lukas Graham': ['danish pop', 'scandipop'],
#  'Naomi Scott': ['movie tunes', 'post-teen pop', 'vapor pop'],
#  'Andrew Rannells': ['broadway', 'show tunes'],
#  'Elijah Woods': ['singer-songwriter pop'],
#  'VaultBoy': ['singer-songwriter pop'],
#  'The Astronomers': ['singer-songwriter pop'],
#  'Catty': [],
#  'Loona': ['k-pop', 'k-pop girl group'],
#  'Fifty Fifty': ['k-pop girl group'],
#  'Drake Milligan': [],
#  'Ram Jam': ['southern rock'],
#  'Holy Goof': ['bass house', 'bassline', 'old school bassline', 'uk dance'],
#  'N2N': [],
#  'Caroline Rose': ['indie pop', 'indie surf', 'vermont indie'],
#  'Honest Men': ['hopebeat'],
#  'River Whyless': ['asheville indie',
#   'folk-pop',
#   'indie folk',
#   'new americana',
#   'north carolina roots',
#   'stomp and flutter',
#   'stomp and holler'],
#  'Flume': ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm',
#   'indietronica'],
#  'Kevin McKay': ['tech house'],
#  'Volac': ['bass house', 'tech house'],
#  'Fedde Le Grand': ['dutch house',
#   'edm',
#   'electro house',
#   'house',
#   'pop dance',
#   'progressive electro house',
#   'progressive house'],
#  'kalika': ['french pop'],
#  'Birds of Bellwoods': ['canadian folk', 'toronto indie'],
#  'Magic Giant': ['folk-pop'],
#  'Sub-Radio': ['dc indie'],
#  'The Click Five': ['boy band', 'neon pop punk', 'pixie', 'pop punk'],
#  'Mates of State': ['kansas indie', 'lawrence ks indie'],
#  'fox capture plan': ['japanese jazz fusion',
#   'japanese math rock',
#   'japanese post-rock'],
#  'Fish in a Birdcage': ['pov: indie'],
#  'Tors': [],
#  'corook': [],
#  'Juniper Vale': [],
#  '(G)I-DLE': ['k-pop girl group'],
#  'FLVR': [],
#  'Xeuphoria': [],
#  'Seiji Igusa': ['japanese guitar'],
#  'Rhett And Link': ['antiviral pop'],
#  'Lauv': ['pop'],
#  'Sam Fischer': ['australian pop', 'singer-songwriter pop'],
#  'Ilsey': [],
#  'Zayn': ['pop', 'uk pop'],
#  'Mena Massoud': ['movie tunes', 'show tunes'],
#  'The Chicks': ['contemporary country', 'country', 'country dawn'],
#  'Rihanna': ['barbadian pop', 'pop', 'urban contemporary'],
#  'Old Crow Medicine Show': ['indie folk',
#   'modern old-time',
#   'new americana',
#   'old-time',
#   'progressive bluegrass',
#   'stomp and holler'],
#  'Christy Altomare': ['broadway', 'show tunes'],
#  'Brian Stokes Mitchell': ['broadway', 'show tunes'],
#  'Paul Lynde': [],
#  'Hiroyuki Sawano': ['anime score', 'japanese soundtrack'],
#  'Bobacupcake': [],
#  'XHz Official': [],
#  'Ben Levin': [],
#  'brian david gilbert': [],
#  'Jazz Emu': [],
#  'Benét Monteiro': [],
#  'mididuck': [],
#  'Marshmello': ['brostep', 'edm', 'pop', 'progressive electro house'],
#  'Dick Gautier': [],
#  'Octavia Spencer': [],
#  'Hilight Tribe': ['didgeridoo'],
#  'Bo Burnham': ['comic', 'pov: indie'],
#  'Lau Noah': [],
#  'Rema Webb': [],
#  'Clark Johnsen': ['show tunes'],
#  'Lewis Cleale': ['show tunes'],
#  'Nikki M. James': ['broadway', 'show tunes'],
#  'Scott Barnhardt': [],
#  'Michael Potts': [],
#  'Three Dog Night': ['album rock',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'soft rock'],
#  'Farsjön': [],
#  'Leo': ['corrido', 'musica mexicana', 'sad sierreno', 'sierreno'],
#  'Mia Rodriguez': ['alt z'],
#  'Fireboy DML': ['afrobeats', 'afropop', 'nigerian pop'],
#  ...}

# %%
# Out:
# ['alt z', 'indie pop', 'pov: indie']

# %%
token
# Out:
# 'BQDgnUUa3hNvO_W_aIExLQx1ptHoyF8cz4KrlxtkLH84HBYByr4gC0iqBjGd4ty_QUn_u9kWk-_ZMOWArrd9LOLKzJMI5Dk-ZjVX5AUYvMCI3lB7VvA3hxkeF9T6T1IGO0GX12Q1zUi3CS66xDUxHqMqwTZUvEb0msAjOZQTZ9xCMiHwI1g1jqy9xddpo6fL3u6GHWD_-WEG6TwKiqjTSASiqQ'

# %%
result = simple_mood_history.join(num_songs_played_by_date(spotify_history), how='outer')

# %%
result = result.dropna()
result
# Out:
#             mood  num_songs_played
# 2022-11-04  good              64.0
# 2022-11-07   meh             102.0
# 2022-11-08   rad              35.0
# 2022-11-09  good              35.0
# 2022-11-10  good               8.0
# ...          ...               ...
# 2023-09-28  good               1.0
# 2023-09-29  good              38.0
# 2023-09-30   rad              26.0
# 2023-10-01  meh+               8.0
# 2023-10-02  good              20.0
#
# [251 rows x 2 columns]

# %%
result.mood.unique()
# Out:
# array(['good', 'meh', 'rad', 'bad', 'S+', 'meh+'], dtype=object)

# %%
mood_mapping = {
    'S+':5,
    'rad':4,
    'good':3,
    'meh+':2,
    'meh':1,
    'bad':0,
}

# %%
correlation = result['mood'].map(mood_mapping).corr(result['num_songs_played'])
correlation
# Out:
# -0.0047747569355806214

# %%
result.groupby("mood").mean("num_songs_played")
# Out:
#       num_songs_played
# mood
# S+           82.625000
# bad          36.500000
# good         36.230769
# meh          70.000000
# meh+         32.500000
# rad          29.524390

# %% [markdown]
# looks like no correlation

# %%
for i in range(100):
    print(spotify_history.iloc[i])
# Out:
# artist                 Penny and Sparrow
# album                              Finch
# song           Don't Wanna Be Without Ya
# date_played    2024-09-27 15:05:00-07:00
# Name: 1, dtype: object
# artist                            Tori Kelly
# album                                   Tori
# song           young gun (feat. Jon Bellion)
# date_played        2024-09-27 15:02:00-07:00
# Name: 2, dtype: object
# artist                    Zac Brown Band
# album                            Uncaged
# song                            The Wind
# date_played    2024-09-27 14:59:00-07:00
# Name: 3, dtype: object
# artist                 Penny and Sparrow
# album                          Olly Olly
# song                              Gogogo
# date_played    2024-09-27 14:55:00-07:00
# Name: 4, dtype: object
# artist                      Taylor Swift
# album                           folklore
# song                               peace
# date_played    2024-09-27 14:51:00-07:00
# Name: 5, dtype: object
# artist                    Zac Brown Band
# album                            Uncaged
# song                    Natural Disaster
# date_played    2024-09-27 14:48:00-07:00
# Name: 6, dtype: object
# artist                      Charlie Puth
# album                            CHARLIE
# song                   Charlie Be Quiet!
# date_played    2024-09-27 14:46:00-07:00
# Name: 7, dtype: object
# artist                          Bon Iver
# album                                 ii
# song                        U (Man Like)
# date_played    2024-09-27 14:43:00-07:00
# Name: 8, dtype: object
# artist                 Penny and Sparrow
# album                              Finch
# song           Don't Wanna Be Without Ya
# date_played    2024-09-27 14:40:00-07:00
# Name: 9, dtype: object
# artist                        Hank Green
# album            This Machine Pwns n00bs
# song                 This Isn't Hogwarts
# date_played    2024-09-27 14:35:00-07:00
# Name: 10, dtype: object
# artist                                       Neil Patrick Harris
# album          Batman: The Brave and the Bold - Mayhem of the...
# song                                                  Death Trap
# date_played                            2024-09-27 14:33:00-07:00
# Name: 11, dtype: object
# artist                                     Leslie Odom Jr.
# album          Hamilton (Original Broadway Cast Recording)
# song                               Washington On Your Side
# date_played                      2024-09-27 14:30:00-07:00
# Name: 12, dtype: object
# artist                                                 The Guild
# album          (Do You Wanna Date My) Avatar (feat. Felicia Day)
# song           (Do You Wanna Date My) Avatar (feat. Felicia Day)
# date_played                            2024-09-27 14:27:00-07:00
# Name: 13, dtype: object
# artist                 Weird Al Yankovic
# album                 The Hamilton Polka
# song                  The Hamilton Polka
# date_played    2024-09-27 14:22:00-07:00
# Name: 14, dtype: object
# artist                 Chameleon Circuit
# album                     Still Got Legs
# song                Everything Is Ending
# date_played    2024-09-27 14:19:00-07:00
# Name: 15, dtype: object
# artist                        Hank Green
# album                           So Jokes
# song               Accio Deathly Hallows
# date_played    2024-09-27 14:15:00-07:00
# Name: 16, dtype: object
# artist              Steam Powered Giraffe
# album                      Quintessential
# song           I Don’t Have a Name For It
# date_played     2024-09-27 14:12:00-07:00
# Name: 17, dtype: object
# artist                                       Neil Patrick Harris
# album          Batman: The Brave and the Bold - Mayhem of the...
# song                                               Drive Us Bats
# date_played                            2024-09-27 14:11:00-07:00
# Name: 18, dtype: object
# artist                                    Thayne Jasperson
# album          Hamilton (Original Broadway Cast Recording)
# song                                        Farmer Refuted
# date_played                      2024-09-27 14:09:00-07:00
# Name: 19, dtype: object
# artist                                  Crazy Ex-Girlfriend Cast
# album          Crazy Ex-Girlfriend: Season 4 (Original Televi...
# song              I Hate Everything But You (feat. Skylar Astin)
# date_played                            2024-09-27 14:06:00-07:00
# Name: 20, dtype: object
# artist                 Chameleon Circuit
# album                  Chameleon Circuit
# song                               Blink
# date_played    2024-09-27 14:03:00-07:00
# Name: 21, dtype: object
# artist                        Hank Green
# album            This Machine Pwns n00bs
# song                              I Know
# date_played    2024-09-27 14:02:00-07:00
# Name: 22, dtype: object
# artist                                            Adventure Time
# album                Adventure Time Vol. 1 (Original Soundtrack)
# song           Oh Fionna (feat. Neil Patrick Harris & Madelei...
# date_played                            2024-09-27 14:01:00-07:00
# Name: 23, dtype: object
# artist                                       Neil Patrick Harris
# album          How I Met Your Music (Original Songs from the ...
# song           Nothin' Suits Me Like a Suit - From How I Met ...
# date_played                            2024-09-27 13:58:00-07:00
# Name: 24, dtype: object
# artist                                              Lewis Cleale
# album          The Book Of Mormon (Original Broadway Cast Rec...
# song                                      Making Things Up Again
# date_played                            2024-09-27 13:54:00-07:00
# Name: 25, dtype: object
# artist                                            Austin Wintory
# album          Stray Gods: The Roleplaying Musical (Pantheon ...
# song                                     The Chorus Is in Accord
# date_played                            2024-09-27 13:52:00-07:00
# Name: 26, dtype: object
# artist                 Chameleon Circuit
# album                     Still Got Legs
# song                       Kiss the Girl
# date_played    2024-09-27 13:49:00-07:00
# Name: 27, dtype: object
# artist                         Hank Green
# album             This Machine Pwns n00bs
# song           A Song about an Anglerfish
# date_played     2024-09-27 13:47:00-07:00
# Name: 28, dtype: object
# artist                                      Jonathan Groff
# album          Hamilton (Original Broadway Cast Recording)
# song                                        You'll Be Back
# date_played                      2024-09-27 13:44:00-07:00
# Name: 29, dtype: object
# artist                                       Neil Patrick Harris
# album          Batman: The Brave and the Bold - Mayhem of the...
# song                                                     If Only
# date_played                            2024-09-27 13:41:00-07:00
# Name: 30, dtype: object
# artist                                              Instrumental
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                            Horrible Credits
# date_played                            2024-09-27 13:39:00-07:00
# Name: 31, dtype: object
# artist                                       Neil Patrick Harris
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                         Everything You Ever
# date_played                            2024-09-27 13:35:00-07:00
# Name: 32, dtype: object
# artist                                       Neil Patrick Harris
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                                    Slipping
# date_played                            2024-09-27 13:33:00-07:00
# Name: 33, dtype: object
# artist                                            Nathan Fillion
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                           Everyone's a Hero
# date_played                            2024-09-27 13:30:00-07:00
# Name: 34, dtype: object
# artist                                                  Ensemble
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                                 So They Say
# date_played                            2024-09-27 13:28:00-07:00
# Name: 35, dtype: object
# artist                                       Neil Patrick Harris
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                               Brand New Day
# date_played                            2024-09-27 13:26:00-07:00
# Name: 36, dtype: object
# artist                                               Felicia Day
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                                Penny's Song
# date_played                            2024-09-27 13:25:00-07:00
# Name: 37, dtype: object
# artist                                       Neil Patrick Harris
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                            A Man's Gotta Do
# date_played                            2024-09-27 13:22:00-07:00
# Name: 38, dtype: object
# artist                                       Neil Patrick Harris
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                                     My Eyes
# date_played                            2024-09-27 13:22:00-07:00
# Name: 39, dtype: object
# artist                                               Felicia Day
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                                Caring Hands
# date_played                            2024-09-27 13:19:00-07:00
# Name: 40, dtype: object
# artist                                                Jed Whedon
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                            Bad Horse Chorus
# date_played                            2024-09-27 13:18:00-07:00
# Name: 41, dtype: object
# artist                                       Neil Patrick Harris
# album          Dr. Horrible's Sing-along Blog (Motion Picture...
# song                                               My Freeze Ray
# date_played                            2024-09-27 13:16:00-07:00
# Name: 42, dtype: object
# artist                                               Mark Ronson
# album                                                    Version
# song           Valerie (Feat. Amy Winehouse) - Version Revisited
# date_played                            2024-09-27 09:46:00-07:00
# Name: 43, dtype: object
# artist                      Harry Styles
# album                          Fine Line
# song                              Golden
# date_played    2024-09-27 09:34:00-07:00
# Name: 44, dtype: object
# artist                                               Mark Ronson
# album                                                    Version
# song           Valerie (Feat. Amy Winehouse) - Version Revisited
# date_played                            2024-09-27 09:27:00-07:00
# Name: 45, dtype: object
# artist                      Harry Styles
# album                          Fine Line
# song                              Golden
# date_played    2024-09-27 09:23:00-07:00
# Name: 46, dtype: object
# artist                     Brooke Fraser
# album             Something in the Water
# song              Something In The Water
# date_played    2024-09-27 09:20:00-07:00
# Name: 47, dtype: object
# artist                            Owl City
# album          Ocean Eyes (Deluxe Version)
# song                               Cave In
# date_played      2024-09-27 09:18:00-07:00
# Name: 48, dtype: object
# artist                    Zac Brown Band
# album                            Uncaged
# song                            The Wind
# date_played    2024-09-25 16:10:00-07:00
# Name: 49, dtype: object
# artist                      Tessa Violet
# album                            YES MOM
# song                             YES MOM
# date_played    2024-09-25 15:51:00-07:00
# Name: 50, dtype: object
# artist                    Earl St. Clair
# album                        Man On Fire
# song                         Man On Fire
# date_played    2024-09-25 15:47:00-07:00
# Name: 51, dtype: object
# artist                     Jacob Collier
# album                      Djesse Vol. 4
# song                    She Put Sunshine
# date_played    2024-09-25 15:44:00-07:00
# Name: 52, dtype: object
# artist                     Hayden Calnin
# album                        Let's Dance
# song                         Let's Dance
# date_played    2024-09-25 15:40:00-07:00
# Name: 53, dtype: object
# artist                      Charlie Puth
# album                  Charlie Be Quiet!
# song                   Charlie Be Quiet!
# date_played    2024-09-25 15:38:00-07:00
# Name: 54, dtype: object
# artist                              Yama
# album                    Haru wo Tsugeru
# song                     Haru wo Tsugeru
# date_played    2024-09-25 15:34:00-07:00
# Name: 55, dtype: object
# artist                             Yelle
# album                   L'Ère du Verseau
# song                    Je t'aime encore
# date_played    2024-09-25 15:31:00-07:00
# Name: 56, dtype: object
# artist                                             Ryan Reynolds
# album          Spirited (Soundtrack from the Apple Original F...
# song                                            Do A Little Good
# date_played                            2024-09-25 15:27:00-07:00
# Name: 57, dtype: object
# artist                    Camila Cabello
# album                             Camila
# song                             Into It
# date_played    2024-09-25 15:24:00-07:00
# Name: 58, dtype: object
# artist                          Big Wild
# album                         Superdream
# song                          6's to 9's
# date_played    2024-09-25 15:21:00-07:00
# Name: 59, dtype: object
# artist                    Lizzy McAlpine
# album                   Give Me A Minute
# song                           Apple Pie
# date_played    2024-09-25 15:16:00-07:00
# Name: 60, dtype: object
# artist                         Novo Amor
# album               Cannot Be Whatsoever
# song                           Halloween
# date_played    2024-09-25 15:13:00-07:00
# Name: 61, dtype: object
# artist                 Haley Heynderickx
# album                           Foxglove
# song                            Foxglove
# date_played    2024-09-25 15:10:00-07:00
# Name: 62, dtype: object
# artist                     The Oh Hellos
# album                      Dear Wormwood
# song                   Soldier Poet King
# date_played    2024-09-25 15:07:00-07:00
# Name: 63, dtype: object
# artist                                               girl in red
# album          we fell in love in october / October Passed Me By
# song                                  we fell in love in october
# date_played                            2024-09-25 15:03:00-07:00
# Name: 64, dtype: object
# artist                     The Lumineers
# album                          Cleopatra
# song                             Ophelia
# date_played    2024-09-25 15:01:00-07:00
# Name: 65, dtype: object
# artist                       Fleet Foxes
# album                        Fleet Foxes
# song                Blue Ridge Mountains
# date_played    2024-09-25 14:54:00-07:00
# Name: 66, dtype: object
# artist                          Bon Iver
# album                    S P E Y S I D E
# song                     S P E Y S I D E
# date_played    2024-09-25 14:50:00-07:00
# Name: 67, dtype: object
# artist                    Gregory Alan Isakov
# album          This Empty Northern Hemisphere
# song                            Big Black Car
# date_played         2024-09-25 14:47:00-07:00
# Name: 68, dtype: object
# artist                                    Frank Sinatra
# album          September Of My Years (Expanded Edition)
# song                                Don't Wait Too Long
# date_played                   2024-09-25 14:44:00-07:00
# Name: 69, dtype: object
# artist                     Nat King Cole
# album                  Love Is The Thing
# song                When Sunny Gets Blue
# date_played    2024-09-25 14:42:00-07:00
# Name: 70, dtype: object
# artist                         Paul Bley
# album                          Paul Bley
# song                       Autumn Breeze
# date_played    2024-09-25 14:38:00-07:00
# Name: 71, dtype: object
# artist                                         Frank Sinatra
# album                                      Moonlight Sinatra
# song           The Moon Was Yellow (And the Night Was Young)
# date_played                        2024-09-25 14:35:00-07:00
# Name: 72, dtype: object
# artist            The Head and the Heart
# album             The Head and The Heart
# song                  Down In The Valley
# date_played    2024-09-25 14:29:00-07:00
# Name: 73, dtype: object
# artist                        Ed Sheeran
# album                  Autumn Variations
# song                       American Town
# date_played    2024-09-25 14:25:00-07:00
# Name: 74, dtype: object
# artist                     José González
# album                             Veneer
# song                          Heartbeats
# date_played    2024-09-25 14:23:00-07:00
# Name: 75, dtype: object
# artist                         Mon RovÎa
# album                  crooked the road.
# song                   crooked the road.
# date_played    2024-09-25 14:20:00-07:00
# Name: 76, dtype: object
# artist                          Taylor Swift
# album              evermore (deluxe version)
# song           it’s time to go - bonus track
# date_played        2024-09-25 14:16:00-07:00
# Name: 77, dtype: object
# artist                                       Noah Kahan
# album          Stick Season (We'll All Be Here Forever)
# song                                         Dial Drunk
# date_played                   2024-09-25 14:12:00-07:00
# Name: 78, dtype: object
# artist                                             The Shins
# album          Oh Inverted World (20th Anniversary Remaster)
# song                               New Slang - 2021 Remaster
# date_played                        2024-09-25 14:08:00-07:00
# Name: 79, dtype: object
# artist                    Lizzy McAlpine
# album                  five seconds flat
# song                            ceilings
# date_played    2024-09-25 14:05:00-07:00
# Name: 80, dtype: object
# artist                     The Oh Hellos
# album                              Notos
# song                      Constellations
# date_played    2024-09-25 14:01:00-07:00
# Name: 81, dtype: object
# artist                    Mumford & Sons
# album                              Delta
# song                       Guiding Light
# date_played    2024-09-25 13:58:00-07:00
# Name: 82, dtype: object
# artist               Gregory Alan Isakov
# album               That Sea The Gambler
# song                     The Stable Song
# date_played    2024-09-25 13:52:00-07:00
# Name: 83, dtype: object
# artist                   Phoebe Bridgers
# album               Stranger in the Alps
# song                     Motion Sickness
# date_played    2024-09-25 13:48:00-07:00
# Name: 84, dtype: object
# artist                      Jack Johnson
# album                  In Between Dreams
# song                     Banana Pancakes
# date_played    2024-09-25 13:45:00-07:00
# Name: 85, dtype: object
# artist                                              James Bay
# album                                            Up All Night
# song           Up All Night (with The Lumineers & Noah Kahan)
# date_played                         2024-09-25 13:41:00-07:00
# Name: 86, dtype: object
# artist                        Noah Kahan
# album                       Stick Season
# song                   She Calls Me Back
# date_played    2024-09-25 13:36:00-07:00
# Name: 87, dtype: object
# artist          Electric Light Orchestra
# album                          Discovery
# song                 Don't Bring Me Down
# date_played    2024-09-25 13:32:00-07:00
# Name: 88, dtype: object
# artist               The Doobie Brothers
# album                 The Captain and Me
# song                  Long Train Runnin'
# date_played    2024-09-25 13:29:00-07:00
# Name: 89, dtype: object
# artist                       Mungo Jerry
# album                  In The Summertime
# song                   In the Summertime
# date_played    2024-09-25 13:25:00-07:00
# Name: 90, dtype: object
# artist                      The Foundations
# album          Baby Now That I've Found You
# song           Build Me Up Buttercup - Mono
# date_played       2024-09-25 13:22:00-07:00
# Name: 91, dtype: object
# artist                   Three Dog Night
# album                          Naturally
# song                    Joy to the World
# date_played    2024-09-25 13:18:00-07:00
# Name: 92, dtype: object
# artist                            Walk the Moon
# album          Walk The Moon (Expanded Edition)
# song                                   Iscariot
# date_played           2024-09-25 13:18:00-07:00
# Name: 93, dtype: object
# artist                Rodrigo y Gabriela
# album                          Mettal EP
# song                           Holy Wars
# date_played    2024-09-24 17:45:00-07:00
# Name: 94, dtype: object
# artist                              Mika
# album                 No Place in Heaven
# song           Promiseland - Bonus Track
# date_played    2024-09-24 17:42:00-07:00
# Name: 95, dtype: object
# artist                                Marvin Gaye
# album          Let's Get It On (Expanded Edition)
# song                              Let's Get It On
# date_played             2024-09-24 17:37:00-07:00
# Name: 96, dtype: object
# artist                              Norman Greenbaum
# album          Music From The Motion Picture Michael
# song              Spirit In The Sky - Deluxe Edition
# date_played                2024-09-24 17:33:00-07:00
# Name: 97, dtype: object
# artist                Rodrigo y Gabriela
# album                 Rodrigo y Gabriela
# song                         Diablo Rojo
# date_played    2024-09-24 17:28:00-07:00
# Name: 98, dtype: object
# artist                                         Europe
# album          The Final Countdown (Expanded Edition)
# song                              The Final Countdown
# date_played                 2024-09-24 17:23:00-07:00
# Name: 99, dtype: object
# artist                       MisterWives
# album                         mini bloom
# song                             the end
# date_played    2024-09-24 17:20:00-07:00
# Name: 100, dtype: object
